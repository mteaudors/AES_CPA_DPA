# %% [markdown]
# # Converting traces in raw format

# %% [markdown]
# In this prerequisite part, we will first change the trace format, from the npy generated by the capture, to a "raw" format, simply consisting of writing the different values measured consecutively. Of course, the number of samples in one trace and the number of traces must be kept alongside the file (for example in a header file with #define).
# First, let us make a capture.

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEXMEGA'
CRYPTO_TARGET = 'TINYAES128C'

# %%
# %run "Helper_Scripts/Setup_Generic.ipynb"

# %%
fw_path = "../hardware/victims/firmware/simpleserial-aes/simpleserial-aes-{}.hex".format(PLATFORM)

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET"
# cd ../hardware/victims/firmware/simpleserial-aes
# make PLATFORM=$1 CRYPTO_TARGET=$2
# Out:
# rm -f -- simpleserial-aes-CWLITEXMEGA.hex
# rm -f -- simpleserial-aes-CWLITEXMEGA.eep
# rm -f -- simpleserial-aes-CWLITEXMEGA.cof
# rm -f -- simpleserial-aes-CWLITEXMEGA.elf
# rm -f -- simpleserial-aes-CWLITEXMEGA.map
# rm -f -- simpleserial-aes-CWLITEXMEGA.sym
# rm -f -- simpleserial-aes-CWLITEXMEGA.lss
# rm -f -- objdir/*.o
# rm -f -- objdir/*.lst
# rm -f -- simpleserial-aes.s simpleserial.s XMEGA_AES_driver.s uart.s usart_driver.s xmega_hal.s aes.s aes-independant.s
# rm -f -- simpleserial-aes.d simpleserial.d XMEGA_AES_driver.d uart.d usart_driver.d xmega_hal.d aes.d aes-independant.d
# rm -f -- simpleserial-aes.i simpleserial.i XMEGA_AES_driver.i uart.i usart_driver.i xmega_hal.i aes.i aes-independant.i
# .
# -------- begin --------
# avr-gcc (GCC) 4.9.2
# Copyright (C) 2014 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# .
# Compiling C: simpleserial-aes.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/simpleserial-aes.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/simpleserial-aes.o.d simpleserial-aes.c -o objdir/simpleserial-aes.o
# .
# Compiling C: .././simpleserial/simpleserial.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/simpleserial.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/simpleserial.o.d .././simpleserial/simpleserial.c -o objdir/simpleserial.o
# .
# Compiling C: .././hal/xmega/XMEGA_AES_driver.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/XMEGA_AES_driver.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/XMEGA_AES_driver.o.d .././hal/xmega/XMEGA_AES_driver.c -o objdir/XMEGA_AES_driver.o
# .
# Compiling C: .././hal/xmega/uart.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/uart.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/uart.o.d .././hal/xmega/uart.c -o objdir/uart.o
# .
# Compiling C: .././hal/xmega/usart_driver.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/usart_driver.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/usart_driver.o.d .././hal/xmega/usart_driver.c -o objdir/usart_driver.o
# .
# Compiling C: .././hal/xmega/xmega_hal.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/xmega_hal.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/xmega_hal.o.d .././hal/xmega/xmega_hal.c -o objdir/xmega_hal.o
# .
# Compiling C: .././crypto/tiny-AES128-C/aes.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/aes.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/aes.o.d .././crypto/tiny-AES128-C/aes.c -o objdir/aes.o
# .
# Compiling C: .././crypto/aes-independant.c
# avr-gcc -c -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/aes-independant.lst -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/aes-independant.o.d .././crypto/aes-independant.c -o objdir/aes-independant.o
# .
# Linking: simpleserial-aes-CWLITEXMEGA.elf
# avr-gcc -mmcu=atxmega128d3 -I. -DNO_EXTRA_OPTS -fpack-struct -gdwarf-2 -DSS_VER=SS_VER_1_1 -DHAL_TYPE=HAL_xmega -DPLATFORM=CWLITEXMEGA -DTINYAES128C -DF_CPU=7372800UL -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir/simpleserial-aes.o -I.././simpleserial/ -I.././hal -I.././hal/xmega -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99 -MMD -MP -MF .dep/simpleserial-aes-CWLITEXMEGA.elf.d objdir/simpleserial-aes.o objdir/simpleserial.o objdir/XMEGA_AES_driver.o objdir/uart.o objdir/usart_driver.o objdir/xmega_hal.o objdir/aes.o objdir/aes-independant.o --output simpleserial-aes-CWLITEXMEGA.elf -Wl,-Map=simpleserial-aes-CWLITEXMEGA.map,--cref   -lm
# .
# Creating load file for Flash: simpleserial-aes-CWLITEXMEGA.hex
# avr-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-aes-CWLITEXMEGA.elf simpleserial-aes-CWLITEXMEGA.hex
# .
# Creating load file for EEPROM: simpleserial-aes-CWLITEXMEGA.eep
# avr-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-aes-CWLITEXMEGA.elf simpleserial-aes-CWLITEXMEGA.eep || exit 0
# .
# Creating Extended Listing: simpleserial-aes-CWLITEXMEGA.lss
# avr-objdump -h -S -z simpleserial-aes-CWLITEXMEGA.elf > simpleserial-aes-CWLITEXMEGA.lss
# .
# Creating Symbol Table: simpleserial-aes-CWLITEXMEGA.sym
# avr-nm -n simpleserial-aes-CWLITEXMEGA.elf > simpleserial-aes-CWLITEXMEGA.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    3488	    556	    248	   4292	   10c4	simpleserial-aes-CWLITEXMEGA.elf
# +--------------------------------------------------------
# + Built for platform CW-Lite XMEGA
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, fw_path)
# Out:
# XMEGA Programming flash...
# XMEGA Reading flash...
# Verified flash OK, 4043 bytes

# %%
# Capture Trace
import time
from tqdm import tnrange


ktp = cw.ktp.Basic()
traces = []
N = 1000 # the number of plaintext
nb_samples = 3000
scope.adc.samples = nb_samples
scope.adc.offset = 0

for i in tnrange(N, desc = 'Capturing traces'):
    key, text = ktp.next()  # creation of a pair comprising (fixed) key and text
    
    while True:
        trace = cw.capture_trace(scope, target, text, key) 
        if len(trace.wave) == nb_samples:
            break;
    
    if trace is None:
        continue
    
    traces.append(trace)
# Out:
# HBox(children=(IntProgress(value=0, description='Capturing traces', max=1000, style=ProgressStyle(description_…

# %% [markdown]
# We will now print the first 10 values and write the trace to a file in "raw" format.

# %%
import numpy as np
import os

traces_dir = 'traces'
#os.mkdir(traces_dir)
trace_array = np.asarray([t for t in trace.wave for trace in traces])
"""
print first and last 10 elements

for i in range(10):
    print('%f' % trace_array[i])
print("...")
for i in range(len(trace_array)-10,len(trace_array)):
    print('%f' % trace_array[i])
"""

f = open(os.path.join(traces_dir, 'key.raw'), "wb")
f2 = open(os.path.join(traces_dir, 'plain.raw'), "wb")
f3 = open(os.path.join(traces_dir, 'traces.raw'), "wb")

# same key for all plaintext so write only once
print("key   : ",traces[0].key)
for b in traces[0].key:
        f.write(np.uint8(b))
        
for trace in traces:
    print("plain : ",trace.textin)
    for b in trace.textin:
        f2.write(np.uint8(b))
    for b in trace.wave:
        f3.write(b)
        
f.close()
f2.close()
f3.close()
# Out:
# key   :  CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# plain :  CWbytearray(b'bb 31 f1 98 c5 ca 68 19 4d b3 91 1b 76 22 08 3b')
# plain :  CWbytearray(b'c4 dc a8 01 78 77 f7 3d 0e bd 32 c4 22 98 62 70')
# plain :  CWbytearray(b'64 ee be da 1c 8d 2a 48 81 d1 2c 37 e8 7a 26 5c')
# plain :  CWbytearray(b'98 31 a1 d0 58 2c c0 40 55 20 b7 b5 d5 91 ba 83')
# plain :  CWbytearray(b'f4 c1 af b3 7c 8e c8 fe 6d 1a 4c 1c 69 d3 2a bc')
# plain :  CWbytearray(b'35 e1 43 dd ee 56 9f 97 54 a8 df f8 5e e4 c5 28')
# plain :  CWbytearray(b'11 80 84 40 8e 62 68 51 a1 6b fb d7 b1 71 bb eb')
# plain :  CWbytearray(b'62 4b 94 34 f2 08 4a dd 59 94 27 e3 a4 3f 11 86')
# plain :  CWbytearray(b'ac a0 eb f9 48 58 a3 36 58 a1 c9 c3 21 a0 1f 5c')
# plain :  CWbytearray(b'b9 e2 58 dd 91 53 a4 82 be 17 05 7c 43 86 32 ee')
# plain :  CWbytearray(b'59 c9 16 11 55 d0 f7 35 d8 b5 0c 3a c7 bc 7a 4b')
# plain :  CWbytearray(b'84 9a fb de 25 1b c3 94 89 b4 89 c7 97 49 7f a3')
# plain :  CWbytearray(b'18 26 63 80 2f 9a 4b 86 27 cb f9 a5 4f 3d c9 46')
# plain :  CWbytearray(b'4b d2 3c d1 eb ba a2 9e 6e 51 0d 73 ed 97 9a 91')
# plain :  CWbytearray(b'1c e6 9e 7e a9 04 76 a9 df ae 9e 30 6a 3c 26 27')
# plain :  CWbytearray(b'0b 34 bb c9 a8 26 22 e1 48 58 47 bc 09 e5 7e c2')
# plain :  CWbytearray(b'e7 1e d5 28 ca ce 5a 9f 52 5a 22 3b 90 d0 9c 87')
# plain :  CWbytearray(b'0d 07 59 a0 04 4e 07 ea 84 94 fc 63 e4 48 b9 ce')
# plain :  CWbytearray(b'8d 24 c5 d3 c7 42 cd fd 32 d2 f7 c3 d5 58 4b 12')
# plain :  CWbytearray(b'88 2f 84 97 83 7e c8 f2 11 d8 8b 1e 7e 12 ad 8d')
# plain :  CWbytearray(b'6b 44 54 ce a8 07 e2 55 55 00 12 d9 60 b2 c3 28')
# plain :  CWbytearray(b'e2 25 df 1f 20 26 c6 fb c5 f4 f9 8b b5 10 84 a6')
# plain :  CWbytearray(b'eb 79 30 4e 62 2c b6 a8 78 eb f6 de da 93 ac 9f')
# plain :  CWbytearray(b'1d 7f 00 e9 88 f8 a1 12 52 1d 0d 33 89 22 6f 4e')
# plain :  CWbytearray(b'c3 e8 20 c9 49 d0 c1 d1 67 66 4d ce 40 bf 04 c6')
# plain :  CWbytearray(b'c5 e6 c5 cb 5b 35 ea 21 18 e0 4f bb e2 b7 9d 8f')
# plain :  CWbytearray(b'8e 69 90 d5 11 5f ac 6a df 17 61 bc 05 2c de d7')
# plain :  CWbytearray(b'20 f7 98 6e 84 4b b9 d0 b9 9e 63 d6 70 57 b3 2f')
# plain :  CWbytearray(b'0d a8 82 2d 58 7d bd d1 82 98 fb 2d 4d 1d 0f 8b')
# plain :  CWbytearray(b'59 18 fb 7f 61 4b 2b e1 d2 05 23 76 00 0b 0d 73')
# plain :  CWbytearray(b'bd 82 0c 17 ab 32 e9 f7 8b 19 37 94 1c 16 a0 eb')
# plain :  CWbytearray(b'c2 61 83 40 a2 6d 90 bf 5f 9f ce c9 fc 27 00 39')
# plain :  CWbytearray(b'6e 37 3e da f3 f1 12 b9 6b 55 bb 09 22 64 fc 29')
# plain :  CWbytearray(b'58 53 56 ea a4 a9 f0 5b 40 c7 2c 66 94 e7 f9 07')
# plain :  CWbytearray(b'29 3a d4 1e af f3 b2 0c b4 a8 9e e9 44 21 e5 10')
# plain :  CWbytearray(b'82 5f 9d 19 06 4e 88 12 d6 7b a3 64 4c cf d6 b1')
# plain :  CWbytearray(b'57 82 19 9a 81 c2 cc a0 05 8a af bb 50 c8 66 dd')
# plain :  CWbytearray(b'16 b0 16 c3 d2 20 d5 11 1a e5 47 84 7c e7 cb d9')
# plain :  CWbytearray(b'2f 2d d1 51 4b d8 97 b3 4b 11 0f c3 09 5e a1 99')
# plain :  CWbytearray(b'44 35 01 11 b0 81 2e d0 49 08 61 31 3c 89 d2 5d')
# plain :  CWbytearray(b'c4 8d de b1 ad 26 6e 31 fd 87 6d 8c f9 d5 cc 4c')
# plain :  CWbytearray(b'98 e0 27 68 fc 32 ba 23 b8 42 68 49 2f 14 04 12')
# plain :  CWbytearray(b'97 b8 28 52 6a 55 67 72 00 85 72 ae c1 bf 1a 61')
# plain :  CWbytearray(b'c4 ef fa e5 96 43 93 4d 2d 45 55 9e f5 48 d6 1a')
# plain :  CWbytearray(b'5b 56 a5 f3 17 e2 ef f3 37 9a c1 ac a2 b9 e7 f0')
# plain :  CWbytearray(b'85 5d 42 6d 08 a2 47 55 d5 82 d2 1c ec 18 37 02')
# plain :  CWbytearray(b'd9 99 04 08 db 97 b8 54 2e a6 a3 05 85 06 cd 99')
# plain :  CWbytearray(b'75 cf 5e 8b d3 b2 33 6f e0 0f 22 15 ac cc 93 d3')
# plain :  CWbytearray(b'67 58 9a f7 88 40 b7 bb 33 16 3c f1 3f 19 c5 36')
# plain :  CWbytearray(b'09 5f 60 34 f6 7b 20 60 f4 e2 6f 04 16 fd 8b 53')
# plain :  CWbytearray(b'99 c6 57 6e 78 36 5b 0f 8b 09 d7 c9 e1 45 9c cf')
# plain :  CWbytearray(b'41 cc b0 91 f9 0f 2a ab 33 de 9c 23 da 54 d8 04')
# plain :  CWbytearray(b'93 e9 fe 58 29 6e 89 3d 73 1c 03 69 c9 f3 d3 05')
# plain :  CWbytearray(b'bd b3 14 29 c7 8d 1b 43 34 9f 11 32 28 70 98 a0')
# plain :  CWbytearray(b'65 2d e8 e0 1e 7c b5 ef a8 54 26 24 3d e6 e3 11')
# plain :  CWbytearray(b'65 b8 84 3c b3 a4 44 b0 d5 59 47 8c 92 ca d3 6d')
# plain :  CWbytearray(b'5f 8d 6a 78 60 c2 5a 2c 1b 53 e9 88 dc 26 05 f3')
# plain :  CWbytearray(b'03 d5 e5 84 fd db 97 21 e5 36 d5 3e fa 8d 92 7e')
# plain :  CWbytearray(b'63 52 9c de 3c 55 83 f4 cc 4e 81 df 4e 51 54 77')
# plain :  CWbytearray(b'76 3d a3 d5 00 0a ea 07 a7 88 15 64 89 0e bc 92')
# plain :  CWbytearray(b'69 cd 30 19 83 c1 f8 32 ce 05 6e 66 2a 0a bf ca')
# plain :  CWbytearray(b'16 c0 ac 3a e2 d2 a3 4d fc 20 73 45 fa 61 69 4d')
# plain :  CWbytearray(b'97 ab 4e 90 97 2c 03 48 73 8c 23 e5 96 e1 7b ac')
# plain :  CWbytearray(b'35 42 5c 9f e8 92 74 8d 0d cd 7a de 1e df 51 bf')
# plain :  CWbytearray(b'00 6f b7 49 31 17 95 01 4b d7 e6 e6 aa 6e 60 37')
# plain :  CWbytearray(b'2a d1 64 42 24 d7 d0 4a ec 8b 9d a8 34 ed a2 a0')
# plain :  CWbytearray(b'2c 72 df c4 7c af 46 f4 de 3f b5 3c 27 c8 46 49')
# plain :  CWbytearray(b'7f 91 3e 86 91 45 79 5e 5a 2e a9 d4 c8 97 84 ac')
# plain :  CWbytearray(b'a6 1d 21 4d 95 62 0d 3d 2e 6a 68 2a e4 29 2e c3')
# plain :  CWbytearray(b'a1 ec f9 39 10 e8 35 8e 74 b9 6a 58 ee 78 6f 02')
# plain :  CWbytearray(b'e2 a4 24 37 56 2d c1 58 5c fc fb 14 14 a4 99 7d')
# plain :  CWbytearray(b'37 97 79 85 67 b1 57 12 e9 a1 c5 a0 09 9c 0c f7')
# plain :  CWbytearray(b'0f f4 4a 3b 51 43 3b 0a cb ef 16 9f 03 e7 db 08')
# plain :  CWbytearray(b'43 e7 5c 90 79 23 d3 a9 2d 43 11 8d 20 92 a9 bf')
# plain :  CWbytearray(b'4d 86 a9 ab 3f 87 14 0a 4e 45 da 20 20 bb b2 50')
# plain :  CWbytearray(b'a7 4f ce 3a 98 09 92 fc dd 56 e2 3f 10 30 d1 3e')
# plain :  CWbytearray(b'60 5a 7e 75 b9 a6 97 f8 29 f9 df b8 7c 47 96 c7')
# plain :  CWbytearray(b'34 b8 dd 6b c9 e3 92 7f 8c 80 99 4f 01 d1 8c 6b')
# plain :  CWbytearray(b'94 85 2d bb af a7 c6 ed 1b 10 e5 14 4b fe 61 d3')
# plain :  CWbytearray(b'c1 fc d1 6a b7 fa 58 47 41 1f 8e 5b 89 6a a6 35')
# plain :  CWbytearray(b'3b 97 b2 90 5c 64 dc ef 31 fc 5d 7b 9a 17 fb 12')
# plain :  CWbytearray(b'ff c6 69 2a 10 05 53 d5 b4 4d 4c 5c 78 89 fc f4')
# plain :  CWbytearray(b'd1 1f da d2 f5 b1 ae cb 94 92 9a 38 88 f6 89 c2')
# plain :  CWbytearray(b'81 89 50 03 62 58 20 2e 2e 2b 0a 23 fa 2f 0b 31')
# plain :  CWbytearray(b'ec 73 79 e7 a4 4b 4b c4 ca 65 7d 2a 00 89 3a d1')
# plain :  CWbytearray(b'a0 2c 7c 7e eb 45 e8 69 74 98 47 4c 50 b8 b6 32')
# plain :  CWbytearray(b'1f ab 5a c5 4d 92 3a 6a 1e 0a 6b 09 4c 5d bb ca')
# plain :  CWbytearray(b'10 a7 64 7e ae b9 25 7a c3 31 d6 32 a9 8a 75 89')
# plain :  CWbytearray(b'ba af 2a fe f9 92 f7 3f 20 5a 7d 2d 34 cf ae 60')
# plain :  CWbytearray(b'c0 6a f3 08 76 9a 0b a4 ac f8 6f a5 25 e3 76 7e')
# plain :  CWbytearray(b'43 26 85 33 63 1a 4e 36 79 3f 6a 92 20 39 ae db')
# plain :  CWbytearray(b'af 93 60 b6 39 8b b3 fe 22 03 d8 2b 33 39 e9 29')
# plain :  CWbytearray(b'b1 75 31 bb e7 c9 68 d8 7a 85 11 be 3c 13 bc d9')
# plain :  CWbytearray(b'f7 dd f0 79 6d 45 92 76 b6 27 94 90 4c c5 23 96')
# plain :  CWbytearray(b'c9 f2 8f ca 00 d7 1e d7 0b e9 de ab 5e 85 29 8a')
# plain :  CWbytearray(b'af 34 64 41 49 8d e7 c4 7a 93 7a 6f 9b ed 6a 2e')
# plain :  CWbytearray(b'40 77 23 86 8d 7e 49 87 2b 0a 42 d9 a4 38 df cb')
# plain :  CWbytearray(b'c6 0b f7 6b b0 7a 32 bb bc 61 9c a0 03 46 89 f9')
# plain :  CWbytearray(b'70 67 83 24 b2 aa fc e2 56 03 0a 57 88 1e 8d ae')
# plain :  CWbytearray(b'03 ad 5e a8 da fc 67 3e 40 2f 3d bb 4a c3 2e f5')
# plain :  CWbytearray(b'5f 75 a3 aa 37 9d cf d0 da d8 a1 f1 b0 74 a8 77')
# plain :  CWbytearray(b'53 81 e0 9a ea cf 7d 23 17 d6 5c 47 f0 58 e9 61')
# plain :  CWbytearray(b'76 be b4 38 74 af 99 3c 1c bb 45 3f 5a ef 39 a0')
# plain :  CWbytearray(b'c2 bb b7 97 65 15 47 27 e7 03 7f 77 a6 1c bb 45')
# plain :  CWbytearray(b'ad 53 d6 cc c7 b8 a3 4d 04 9e 57 19 78 37 12 a4')
# plain :  CWbytearray(b'a8 6f 9d 42 88 0f bc 51 7f 79 c2 e7 dc 76 3d f3')
# plain :  CWbytearray(b'd4 f7 b8 fb 71 db 1b a7 de 9f 4d 1c ee 41 7b 95')
# plain :  CWbytearray(b'67 19 33 ce a5 b8 ff d8 10 87 ce e6 56 4d 85 65')
# plain :  CWbytearray(b'fa 9a 5d 0c ab 9c a3 0c 92 cc 63 21 66 42 52 f3')
# plain :  CWbytearray(b'd3 8e 7e 8b db 15 8d 31 45 87 17 4e 4c db fa 85')
# plain :  CWbytearray(b'01 ff f0 63 82 e0 a4 e9 c9 7a 32 98 61 ce 8d 38')
# plain :  CWbytearray(b'29 b8 81 d9 c3 2c bc 53 e6 82 33 cc 9b a5 34 f8')
# plain :  CWbytearray(b'3d 83 99 d4 44 09 dd 85 c1 26 59 a1 52 a3 bd 34')
# plain :  CWbytearray(b'3a a2 f9 28 ba b6 c5 89 c7 bd 5a 72 fa 60 6f 20')
# plain :  CWbytearray(b'16 71 92 2f 3e a0 dd c1 b0 7d 03 cf 2f c5 45 28')
# plain :  CWbytearray(b'fa 3a 96 b0 91 33 55 0d 85 b5 77 1a 9e cc 32 bb')
# plain :  CWbytearray(b'62 89 8a 0d 3f 63 e2 cb c9 03 e0 de c5 15 d7 01')
# plain :  CWbytearray(b'38 c8 b6 72 27 2b 6c f7 2b f0 bf 70 cc a2 79 da')
# plain :  CWbytearray(b'bf 90 8e 7e cb 2d ec 8d 3c 1d 03 74 9d 9c 4c 10')
# plain :  CWbytearray(b'6f 98 a4 27 b4 5d c9 bd d7 32 a0 9a 61 55 0d 49')
# plain :  CWbytearray(b'22 a3 23 a4 2b 3c e6 cf 17 ff 1d c2 32 92 2c 4d')
# plain :  CWbytearray(b'df 40 7f 01 2f ed 1c f6 36 b0 0d de 1c b2 05 d2')
# plain :  CWbytearray(b'ab f7 64 9b d7 64 ea d6 41 59 ac eb 68 59 df 61')
# plain :  CWbytearray(b'e0 23 48 7e 37 92 2f e9 5b 8e 16 17 d9 3a 91 f4')
# plain :  CWbytearray(b'c9 20 50 c1 05 ae cb 39 5f f8 24 e5 35 4a d6 94')
# plain :  CWbytearray(b'0e 37 1c 5b 12 16 27 76 74 64 75 1d 11 b8 72 7b')
# plain :  CWbytearray(b'97 44 d5 39 d3 a2 49 0c ed fa ef fc 94 69 30 c9')
# plain :  CWbytearray(b'23 08 36 da e2 ab 78 2c f8 7e 58 0a dc c7 d4 3e')
# plain :  CWbytearray(b'ee 50 f1 02 ef 75 e0 3e af b8 d5 7b 85 1c 3b e6')
# plain :  CWbytearray(b'e8 c9 58 d6 35 0b ee 52 f9 c8 ee 53 da ae 65 fa')
# plain :  CWbytearray(b'6b d8 59 a6 b2 1d 9b 9b 7b ee 8c 4b 96 48 ea 1c')
# plain :  CWbytearray(b'01 c6 57 cb 40 6e 8a b4 ad 95 8c 72 3e 18 ed 32')
# plain :  CWbytearray(b'6a 6a 1c 23 0e 86 ff 3d 88 4d dc 6f 7c e4 e0 30')
# plain :  CWbytearray(b'66 d7 15 ba 3e 7d b2 fc 25 7c 65 40 92 0b 21 d5')
# plain :  CWbytearray(b'83 4f 69 04 51 6a 3e 08 24 72 5c 91 8d 02 9f 74')
# plain :  CWbytearray(b'28 2f 34 99 a0 2a 58 e0 fd 17 2d c9 3f 1a 74 f7')
# plain :  CWbytearray(b'f4 44 84 86 f4 7e 56 08 3a 02 3f e3 75 d5 2c e1')
# plain :  CWbytearray(b'9f f5 74 85 6f 9e e9 f2 6d 03 6a a1 67 22 7b 24')
# plain :  CWbytearray(b'57 c1 60 04 5d 6a 02 ca 9f 09 a1 0f 7f 9d 9d 58')
# plain :  CWbytearray(b'52 ba fd fb e8 94 21 f1 68 38 44 87 7d dd 5c 1e')
# plain :  CWbytearray(b'9a 91 73 49 3d 4c 42 cd 62 e3 82 68 3c 7a 65 d4')
# plain :  CWbytearray(b'44 4f 59 bd 0f 54 0a b4 b2 db 27 ba 61 be c7 0f')
# plain :  CWbytearray(b'44 3d 5b 1e 9d a3 90 39 de d6 2a 6a b5 0c f3 89')
# plain :  CWbytearray(b'c6 40 a6 c6 b5 55 c5 9f a0 ec 53 e6 67 3d 04 99')
# plain :  CWbytearray(b'c7 bf d1 bb ca 3c 9f 94 a1 80 27 76 0e 59 c3 35')
# plain :  CWbytearray(b'a9 64 bc 18 43 e6 ef b4 e0 7f aa 88 f8 45 85 95')
# plain :  CWbytearray(b'cb 45 af da 71 69 25 8b 5c d7 70 24 69 b0 0c 0b')
# plain :  CWbytearray(b'9e 09 16 ca 2d 6f 7d 2f e4 93 b7 dd d4 eb 13 97')
# plain :  CWbytearray(b'73 93 b8 c4 eb 1f 37 0e c4 f4 57 8a c7 de 9a c4')
# plain :  CWbytearray(b'3e 9a 33 27 d0 17 8c 54 fe db 77 23 7a d3 26 cf')
# plain :  CWbytearray(b'5d f1 f9 0e 0a d8 c2 7e 44 c9 79 04 ba a6 5e 6e')
# plain :  CWbytearray(b'6b b3 12 09 63 a7 20 f0 14 9b 58 25 13 15 2c 70')
# plain :  CWbytearray(b'7d 55 36 cb f2 b9 76 43 7f 0e 0b 48 bc e4 6d 6d')
# plain :  CWbytearray(b'1e cc c9 e9 db 0d d7 9f c8 77 9c f6 40 46 93 bf')
# plain :  CWbytearray(b'ba ae c0 89 51 0b 76 d5 12 42 65 2c 4d 04 28 d8')
# plain :  CWbytearray(b'38 b5 31 93 1d f2 97 de 7a 08 0c d6 0d 13 1c 74')
# plain :  CWbytearray(b'fa 3b 2d 8b cd 27 3c 1a 25 5f 76 d0 64 34 e8 61')
# plain :  CWbytearray(b'66 2e 01 1b ac 36 2f d7 56 ae f0 5a b9 43 49 7d')
# plain :  CWbytearray(b'57 1f 98 62 fe 63 73 ac 52 ba d2 83 ed 5b 85 9b')
# plain :  CWbytearray(b'81 2c b0 bb f0 17 1e 16 94 2b 44 ca 5f 21 4c 91')
# plain :  CWbytearray(b'af 83 f2 ca 19 75 d6 10 fa 70 06 84 33 ae f4 49')
# plain :  CWbytearray(b'20 e0 01 dd 16 8c a2 91 8b 5a 1c 1c 4a 1b ff ab')
# plain :  CWbytearray(b'11 c8 75 37 1d 31 40 39 79 46 a9 00 19 8a 2a 80')
# plain :  CWbytearray(b'14 db 14 c2 9c f3 97 7a f2 0f 03 6f ce 19 95 5b')
# plain :  CWbytearray(b'91 4f a2 21 7f 8f c9 bf c2 59 93 c7 22 d5 ec d5')
# plain :  CWbytearray(b'9a 7e 33 b5 93 35 41 cf fe d8 f2 cf da eb 49 09')
# plain :  CWbytearray(b'3d 44 2d ea 49 ec ba 3d 5f 09 1a 94 37 86 f6 c5')
# plain :  CWbytearray(b'8c 97 5b 41 8d 98 b2 42 8b d0 dc 55 3d a2 8d 44')
# plain :  CWbytearray(b'44 e3 71 c1 82 fb 6b e5 36 1c c6 0a 93 b7 ee d0')
# plain :  CWbytearray(b'63 d4 e7 1b 09 5a 5b ac 34 7b d7 58 7b 33 dd 04')
# plain :  CWbytearray(b'06 f5 00 15 87 63 a4 52 e9 e7 b0 d1 80 93 51 1f')
# plain :  CWbytearray(b'78 a1 19 7c 55 3a 6d 69 0f be 51 62 83 ec a4 30')
# plain :  CWbytearray(b'44 5b 4e 35 cb a3 c1 0b d3 b5 83 1b 88 d5 08 ba')
# plain :  CWbytearray(b'bc 97 5d 92 97 94 ed b6 b1 7d a2 05 f6 7a 96 b3')
# plain :  CWbytearray(b'bd 43 cf cc 44 17 e8 1c 16 dc 11 30 cc 8a d4 f5')
# plain :  CWbytearray(b'b2 73 84 cf df a9 e4 a8 cb 76 fd ce c0 a6 2b 2b')
# plain :  CWbytearray(b'41 a4 75 6f 9c c5 39 2c ac 36 eb 9d f5 9f fa 41')
# plain :  CWbytearray(b'bf 31 9c f0 3c ed 50 80 ca 2e a6 d6 91 88 b0 7c')
# plain :  CWbytearray(b'b8 da f3 8c 77 06 3e 9f 4a 92 4a 86 c3 ac 81 c0')
# plain :  CWbytearray(b'8e 30 32 91 ee 9f 48 fd be 8d d5 03 07 6c 77 d3')
# plain :  CWbytearray(b'62 7f 63 4d df ea 23 62 68 06 ba 47 c6 94 64 f9')
# plain :  CWbytearray(b'cd 93 42 2d 18 df 07 c2 53 d1 9d 66 a6 c8 1c 13')
# plain :  CWbytearray(b'39 68 0f 0e a1 36 9c 61 8a 02 37 e2 35 99 3f 04')
# plain :  CWbytearray(b'69 dd 98 a7 44 8b 8a 7a 6e b2 0a f5 8a 5f bc ed')
# plain :  CWbytearray(b'1b ff 04 96 4e 2d c8 74 b3 43 7a 32 9b 04 f5 fe')
# plain :  CWbytearray(b'48 8e 80 0c 50 c9 99 5b ac 7b d2 28 ff b8 73 cd')
# plain :  CWbytearray(b'32 9c 14 8c 3e d4 fc 23 1a 30 fc 1c c3 65 20 5e')
# plain :  CWbytearray(b'42 04 1f 60 b1 ff a2 12 c9 a2 6e 0e 3a e4 06 be')
# plain :  CWbytearray(b'df 02 6c 73 4e 24 8d fc d0 1c 94 fa 13 aa 52 57')
# plain :  CWbytearray(b'6f c6 6a 2a 62 b0 46 f1 1c 0a 79 8c 0f c3 25 64')
# plain :  CWbytearray(b'c7 ac 25 c6 20 00 ac 0f 78 71 62 80 d3 70 ef c3')
# plain :  CWbytearray(b'90 f8 b5 c4 e5 ce e1 fa 45 19 1b 4e 56 c9 ca 84')
# plain :  CWbytearray(b'32 32 56 b4 47 80 73 11 bf 41 3a 4e fd 91 1c cb')
# plain :  CWbytearray(b'95 3a 62 e7 75 94 cb ed 30 12 b8 74 de 63 25 db')
# plain :  CWbytearray(b'f8 1b 86 12 0c 21 7f 59 c0 77 6e 58 3c d2 25 57')
# plain :  CWbytearray(b'3b 32 2b 7b 20 4d fc fd 8c 0a 01 76 42 99 3d 30')
# plain :  CWbytearray(b'ef 7c cc d7 f7 9f d0 f0 ba a1 f2 9b 32 ca cf b9')
# plain :  CWbytearray(b'16 71 10 c2 73 c7 3e ab 01 72 06 ab ae 9b a6 a0')
# plain :  CWbytearray(b'20 16 08 cc 69 8b a0 a3 7e bd 7f 4c 33 da 76 67')
# plain :  CWbytearray(b'db 65 f4 8f fb 0b 2f c3 a9 07 21 14 94 ea 4f 5b')
# plain :  CWbytearray(b'15 16 83 b2 ef 1f f0 f4 69 fe e9 15 fb 5f b7 1d')
# plain :  CWbytearray(b'9a 4f 1c f5 d2 9c 80 02 62 5b 75 10 bb 71 e5 40')
# plain :  CWbytearray(b'3b eb 76 5b c7 c2 45 6d 63 02 a4 0e 69 8f 36 f1')
# plain :  CWbytearray(b'97 f7 79 f7 4a 3e 0f 5d b8 f2 04 1a 29 67 56 f7')
# plain :  CWbytearray(b'f2 49 cc bb e9 fa 19 96 21 b9 4c 4b 51 e7 71 99')
# plain :  CWbytearray(b'f8 79 c9 a8 7c 9a 51 86 52 5e f3 b0 7c 17 c4 44')
# plain :  CWbytearray(b'17 62 e2 e0 6d af ee 5b d4 ef 67 b7 6f 9a 79 04')
# plain :  CWbytearray(b'53 50 99 73 58 09 ee 5d eb a8 77 18 76 8e a2 0e')
# plain :  CWbytearray(b'79 94 9f 8f ad 79 ac c2 56 91 50 a9 c5 39 aa 28')
# plain :  CWbytearray(b'12 9f 0f a1 9f 54 8d 25 0d 61 cc 7d 5d 08 37 96')
# plain :  CWbytearray(b'17 cb dc a9 cb 27 87 6c 70 47 b1 5a 59 60 90 eb')
# plain :  CWbytearray(b'd5 a0 4c 55 55 5f a1 1c 9f 13 0c 18 68 db 29 ef')
# plain :  CWbytearray(b'd2 8c 77 6b 50 3b d8 27 03 4a a7 31 12 4a 74 da')
# plain :  CWbytearray(b'46 4f 8f 9f 09 ec 97 ed 8c 1d fb a0 80 54 64 5c')
# plain :  CWbytearray(b'ba e7 8c c0 63 06 b5 a0 c8 b8 46 48 fb 5f 62 62')
# plain :  CWbytearray(b'00 33 09 56 72 5c 2e d7 69 21 0c ad f5 e2 e6 04')
# plain :  CWbytearray(b'e8 06 59 3c 15 e2 2f ba 27 91 ca 6b 13 a4 66 bc')
# plain :  CWbytearray(b'c4 e0 b4 a9 8a d5 1b 91 f3 64 ff f9 d3 a7 71 ec')
# plain :  CWbytearray(b'f1 09 76 c3 98 f1 8e 1d cb 42 6b fd ac 6c 6b 0e')
# plain :  CWbytearray(b'd2 31 ee 74 fc fc a7 9e 32 9f 22 07 37 bc 0d f7')
# plain :  CWbytearray(b'dd 7d e5 f3 cc 88 36 b0 db b4 e6 e3 08 0e ff f9')
# plain :  CWbytearray(b'2a 65 67 0c 27 a2 ba 96 22 0d 71 8e 88 d3 5b 5b')
# plain :  CWbytearray(b'a0 aa af bc 09 f7 4f 28 9a 32 43 6b 81 0f 40 c7')
# plain :  CWbytearray(b'9a 97 1d 0f 22 c3 06 2e 6f b2 34 1f 36 5e ce 42')
# plain :  CWbytearray(b'b1 b3 0d 23 f2 a1 15 80 3e cb 53 e0 01 7f 71 8f')
# plain :  CWbytearray(b'f1 b0 40 a3 bc 14 be 68 9a 19 7b dd 08 b5 25 cd')
# plain :  CWbytearray(b'cd b6 8a 7d 51 a2 7d 89 3b c2 28 20 f8 43 aa 99')
# plain :  CWbytearray(b'f5 ce bb a0 3c 2d d0 a6 b0 03 57 ed 40 09 b2 09')
# plain :  CWbytearray(b'c6 9b 3d 25 8f 90 28 1c 60 21 5f 39 37 3b a2 75')
# plain :  CWbytearray(b'fc 5f 11 53 0c 98 5f 82 42 dc d9 3c 7e 65 95 2b')
# plain :  CWbytearray(b'0e b7 54 ed 76 a0 fa 70 76 1d ad 16 3a ff e2 3d')
# plain :  CWbytearray(b'90 4c 28 21 b6 36 c6 ef 7d 1c 97 97 f6 a6 2b 5c')
# plain :  CWbytearray(b'b3 8d 40 13 ac dd f7 58 ec 8b 59 8a e6 b2 ec 2d')
# plain :  CWbytearray(b'3b 20 60 45 3d 3a 61 6e 42 ed 81 97 49 f3 cd 5f')
# plain :  CWbytearray(b'7d 4d 59 99 51 4c 9d 56 f8 1c 22 7c 8e ab fe be')
# plain :  CWbytearray(b'f5 49 c6 99 a7 d9 3a 09 bc 9f b3 4d b8 99 90 56')
# plain :  CWbytearray(b'67 bc c9 0f fb 62 98 30 56 c0 28 e0 b2 61 df 25')
# plain :  CWbytearray(b'9d cd 81 fb d2 0c 19 59 3b b5 3d aa bd 0c d3 00')
# plain :  CWbytearray(b'0b 9d 74 31 86 09 c4 a9 23 85 0a 23 fb 54 6e 8a')
# plain :  CWbytearray(b'd0 14 82 fb 11 95 7d 0f 0d 6a 2e 64 f5 c5 a9 c3')
# plain :  CWbytearray(b'98 9f 3f 8b d7 78 e2 99 3f 8b ef 16 9f 31 f9 0e')
# plain :  CWbytearray(b'b4 75 b7 04 fe a3 56 00 0b ab 51 7f 20 41 23 d8')
# plain :  CWbytearray(b'dc 7f 7b 35 5a d8 07 95 3d 90 18 2f 4b 24 25 e2')
# plain :  CWbytearray(b'e0 57 65 9d 83 46 20 8b 89 28 87 43 63 1c 15 b8')
# plain :  CWbytearray(b'6b 3e 2e 82 2a 3e 41 01 99 23 d9 15 3f 33 a0 22')
# plain :  CWbytearray(b'e5 62 48 33 6b 34 08 4b da 9a ee 78 93 b8 8d 73')
# plain :  CWbytearray(b'ae 9c 99 88 bb 58 83 84 e8 2c c5 68 1d f5 47 ed')
# plain :  CWbytearray(b'50 7c 48 8b 78 bc 97 b3 42 26 0a 07 7e 99 23 66')
# plain :  CWbytearray(b'52 b5 57 e4 6d c6 05 7b 82 5e 9a e4 50 d7 12 8d')
# plain :  CWbytearray(b'60 bd 84 01 e9 70 ee 07 22 d1 21 17 db ec 78 91')
# plain :  CWbytearray(b'c7 23 27 be d4 43 28 18 68 36 08 42 a4 5a db ec')
# plain :  CWbytearray(b'10 93 e9 82 40 76 93 4a 25 0f da a4 c8 f2 c7 fc')
# plain :  CWbytearray(b'93 09 4a c6 d1 ca b2 bc 65 ca be 5f fc 9e d7 88')
# plain :  CWbytearray(b'd3 de 17 c8 10 f4 b7 83 84 80 3c b3 9a 1c c5 cb')
# plain :  CWbytearray(b'cd 3d fe 34 8f 36 41 bd 06 fc 6a a3 e7 61 cd 4a')
# plain :  CWbytearray(b'3f dc cf 35 62 4c b6 d5 65 e2 fb 39 7f 42 73 d8')
# plain :  CWbytearray(b'86 b0 6f 38 2a 0d b7 99 4b 77 4d 9d eb 09 a5 71')
# plain :  CWbytearray(b'd3 56 bc 02 c8 11 86 91 f5 a0 49 18 0f 00 c1 4d')
# plain :  CWbytearray(b'56 ff b9 9b 20 7a 1e cc 2f 0a ae 87 69 8e 2c 04')
# plain :  CWbytearray(b'4f a4 92 0c 70 8a f4 24 72 b6 92 91 4d a5 1a f6')
# plain :  CWbytearray(b'15 68 19 77 4a e6 18 42 6b 3c fc 2f 2e a8 6d c5')
# plain :  CWbytearray(b'29 29 20 3c 9e 1c 80 3f 82 e0 24 63 ca 21 00 74')
# plain :  CWbytearray(b'30 09 e1 53 79 4a 49 8e 00 2f 70 44 36 f6 51 a0')
# plain :  CWbytearray(b'91 f2 79 5e 4a 44 cc f6 8b b1 88 a9 5a d2 9c bb')
# plain :  CWbytearray(b'de 30 a7 18 18 7f 53 a6 a5 c9 81 30 e2 b0 8d 1b')
# plain :  CWbytearray(b'81 96 81 34 2f eb 26 1f 82 dd f9 53 78 6f 2f 0e')
# plain :  CWbytearray(b'7e 35 d6 68 3e ae f3 62 05 28 3b a1 66 cf 67 f0')
# plain :  CWbytearray(b'fa 05 d8 34 ba 84 9a 28 3d 5a 6c 29 e7 a1 13 85')
# plain :  CWbytearray(b'f7 ba 92 b1 80 74 47 b5 23 a3 21 cc d4 bf 83 b1')
# plain :  CWbytearray(b'84 c9 2a 0f 13 30 47 00 dd 81 18 2b fd c8 a9 aa')
# plain :  CWbytearray(b'17 40 65 67 83 6a 8d f8 f4 6d 89 60 82 5e 29 bc')
# plain :  CWbytearray(b'01 55 9a 8d 3c 4b b0 a1 15 e1 eb 61 7f 89 57 7e')
# plain :  CWbytearray(b'4b 27 38 61 44 68 70 b9 74 c5 29 74 14 51 23 2b')
# plain :  CWbytearray(b'45 69 fd e0 33 18 8b b3 0d c3 d5 7f 2d bb bd 70')
# plain :  CWbytearray(b'34 0a 38 8b d2 f2 f2 e1 29 92 c3 a3 6c c8 e0 71')
# plain :  CWbytearray(b'43 dc 91 5c fe 28 dd 3e b5 fa dc bf 29 9d ac fe')
# plain :  CWbytearray(b'67 d8 80 19 04 fb 16 db 6d cc 90 4e 40 1d 87 21')
# plain :  CWbytearray(b'3a 95 27 6b b7 7d 22 c9 7c 30 e3 0c 16 01 6c 60')
# plain :  CWbytearray(b'83 af c8 4c cc a3 31 a7 a9 59 21 86 5f ed 2e 52')
# plain :  CWbytearray(b'36 4e 76 22 fc 1c b0 cb eb b0 1e cd 4e f9 f5 29')
# plain :  CWbytearray(b'48 ed 1c c4 e0 23 50 42 fd a0 f8 bc ba 4b 53 b1')
# plain :  CWbytearray(b'16 cc 30 3f d5 f0 1b 7a c8 cd 39 91 ec d3 db 20')
# plain :  CWbytearray(b'95 0b 9f 8b 43 bc 3b ad 6d ad d3 f3 23 66 c1 e5')
# plain :  CWbytearray(b'04 d7 ab ab cc 36 7e 1f a1 0e d8 16 bd cb 86 30')
# plain :  CWbytearray(b'bc 00 d0 de e0 61 00 26 95 4e 7c f2 d3 6a 49 51')
# plain :  CWbytearray(b'2f c6 1c f8 19 86 66 de 61 06 de ce 08 86 d1 2b')
# plain :  CWbytearray(b'5a a4 e4 66 f2 54 eb bf 88 50 9e 5b ee 27 34 8b')
# plain :  CWbytearray(b'0a a4 c1 c5 39 42 e6 21 99 e8 3f 87 9a 9a 92 91')
# plain :  CWbytearray(b'01 da ac 3f 4a d8 45 67 cc e1 2c 92 ec 6b 80 da')
# plain :  CWbytearray(b'cb 2e dc 38 b8 52 f6 0c 1c 7f a9 fd 20 b1 d7 a0')
# plain :  CWbytearray(b'3b 91 e2 10 80 35 47 83 a5 23 74 79 80 55 2a 5a')
# plain :  CWbytearray(b'0c 74 3f 20 80 c6 42 94 b2 07 46 40 bb 9d 43 98')
# plain :  CWbytearray(b'ed c6 67 2f c0 77 52 74 ca 11 52 ee d3 91 0d 19')
# plain :  CWbytearray(b'5b 56 aa 8d 6e 11 ef 1f 2a 94 cb 8d 42 6c 13 e2')
# plain :  CWbytearray(b'df db bb 80 89 3f c8 a8 e4 7e 43 3c 7b 06 95 b0')
# plain :  CWbytearray(b'8d d7 97 2a 80 f2 9a ac db b2 2c 4d a4 80 2a e0')
# plain :  CWbytearray(b'1c 44 71 81 4f 17 88 bc 4e 70 53 f8 d5 5a 81 8b')
# plain :  CWbytearray(b'14 c2 36 ea c7 2b a2 24 f1 1f 68 e4 30 0e 58 9e')
# plain :  CWbytearray(b'6f 4f 51 58 88 cc 72 23 68 88 3f b7 d0 ff 4f 97')
# plain :  CWbytearray(b'92 fc 23 71 a8 b8 d6 19 93 53 7d 72 2e e1 89 bf')
# plain :  CWbytearray(b'5c 67 a4 c0 5f df ab ff 19 fe a7 74 7a 14 48 09')
# plain :  CWbytearray(b'14 2d 6c d9 1a 99 c9 a9 91 d3 5a ed a0 0d 95 07')
# plain :  CWbytearray(b'6a 32 ff fb b8 35 ce 6c 84 3e ea b0 48 32 c5 b3')
# plain :  CWbytearray(b'63 8f c2 f2 48 e2 97 7e 6f 9e 5d 31 95 81 96 cc')
# plain :  CWbytearray(b'29 b5 be 81 ce d2 47 e5 61 4b 65 d5 03 a4 2a 93')
# plain :  CWbytearray(b'3a a0 dc 6d 82 86 2b 5c a0 1a 99 15 2d ea 4c 03')
# plain :  CWbytearray(b'89 8d 69 51 65 a9 4b 9c 59 ac bd 2e 3e 97 65 50')
# plain :  CWbytearray(b'af fc 36 10 ba a1 80 ee a7 79 6c bd a2 f8 a8 49')
# plain :  CWbytearray(b'61 e5 f8 c6 55 e4 4c a6 f7 77 95 6a ab bb a0 83')
# plain :  CWbytearray(b'ae 43 e6 10 9f 79 0e 01 04 45 8e 5d 35 98 ea d3')
# plain :  CWbytearray(b'eb cc ec ea 99 bd 2e 74 14 9f cb 48 2b ca ad 55')
# plain :  CWbytearray(b'6d a7 d1 c4 ca 14 1c eb 2b a8 00 72 c3 70 94 60')
# plain :  CWbytearray(b'fd 99 08 7a a5 a6 6c 57 3d 7f f4 ea 51 59 bf c3')
# plain :  CWbytearray(b'fa 6b c4 a0 18 49 97 f2 ac 44 74 3b 78 b8 3a 33')
# plain :  CWbytearray(b'eb 20 02 b5 f4 e1 90 71 a7 45 b2 61 94 22 48 0d')
# plain :  CWbytearray(b'43 86 7f d5 bd f9 21 27 81 14 fe 94 59 14 b7 5b')
# plain :  CWbytearray(b'd7 1d 1e a6 56 cc 92 17 c9 85 85 94 aa 3f 48 18')
# plain :  CWbytearray(b'77 72 fb 62 db d4 4f ad c3 58 54 cd 0c e5 62 e8')
# plain :  CWbytearray(b'5b 80 fe 3d 94 04 bc 75 31 92 57 72 95 8a 23 fe')
# plain :  CWbytearray(b'a8 87 c9 43 7b ad 0b 92 2c 05 6b 4a 12 59 62 14')
# plain :  CWbytearray(b'19 aa a4 e0 e6 4e 99 a8 c0 21 0e b8 8f 7d a4 69')
# plain :  CWbytearray(b'dc c5 75 e4 cb 21 8e 08 af 86 af b8 98 67 51 f2')
# plain :  CWbytearray(b'ac 5c 08 f5 78 d2 15 8f 75 27 b6 f2 2a 95 da 94')
# plain :  CWbytearray(b'1b fc 78 09 cf a7 28 10 69 1e fa ed 2b 14 cc 3d')
# plain :  CWbytearray(b'b7 0f ce 48 27 da 7f 77 24 cd 65 7a 53 fa 72 fd')
# plain :  CWbytearray(b'd0 ff 7d 2a 62 31 3c bb 9a 54 ad 43 53 29 52 85')
# plain :  CWbytearray(b'ff 65 3a 3f 59 bd ce 1b cf 9b 64 95 f2 12 16 db')
# plain :  CWbytearray(b'ec 36 ee c1 0c 7a c5 38 49 2d 50 89 d7 a4 85 65')
# plain :  CWbytearray(b'65 ef 43 66 96 8e 88 2f ef f7 ba 2d 5b bb 23 79')
# plain :  CWbytearray(b'b9 3d 74 00 a8 25 7a 0e 8c c2 de 7f 5d 1a 8e 22')
# plain :  CWbytearray(b'c6 9f f2 af 71 85 a2 7d 7b 8b ec 1f ed f2 86 11')
# plain :  CWbytearray(b'85 6b be ac 0b 69 4a 30 1a b5 c0 1d 11 db 9a f5')
# plain :  CWbytearray(b'2f 68 2a 4e 27 93 74 78 51 d1 c4 5a b3 36 02 7c')
# plain :  CWbytearray(b'1d ab 28 26 5a 68 5b 7b e2 de ac fb d3 0f 31 ee')
# plain :  CWbytearray(b'37 eb e0 bb b5 87 32 df 97 cc 7a a4 0d bc 46 30')
# plain :  CWbytearray(b'27 cf bc c0 4c 6b 67 fa 48 f7 fa 12 1e 32 b2 27')
# plain :  CWbytearray(b'df 24 0c 0d 73 5c ca 1d fa be 55 fc fd d8 bb 89')
# plain :  CWbytearray(b'aa 52 7f e5 ed ae a5 bf 77 63 81 04 f4 f6 a6 83')
# plain :  CWbytearray(b'6b 44 8e fd 87 dd bf 5b 63 46 2f fd b2 fc fe 03')
# plain :  CWbytearray(b'ad 36 fc af eb b9 99 d9 c0 f0 2a d6 67 6d 62 77')
# plain :  CWbytearray(b'52 03 d6 a1 81 10 a4 d1 26 51 34 a6 ea d8 68 44')
# plain :  CWbytearray(b'5b 37 42 f0 80 d1 d5 ea 3d ab 0f d7 8a 97 12 56')
# plain :  CWbytearray(b'91 d7 73 59 70 42 ff 7f 97 84 11 d8 34 69 de 86')
# plain :  CWbytearray(b'34 5e 49 c9 f1 fd b4 01 0a 48 5f 77 78 da 5b d9')
# plain :  CWbytearray(b'5e 3f 61 39 08 7f 51 26 dd ce 34 19 3b b3 17 b0')
# plain :  CWbytearray(b'86 80 43 ea e8 ec d8 1b b1 87 c1 a3 b0 b6 b8 dc')
# plain :  CWbytearray(b'1e 59 5a 3a c9 aa 79 cf 89 0b 82 6e 1e 2f 15 cc')
# plain :  CWbytearray(b'b4 f2 ab cf 22 2e da 96 b1 ff 3a 07 4c 86 92 24')
# plain :  CWbytearray(b'45 e0 96 3e 46 25 bd 01 c8 fa 45 f6 76 e4 a8 b4')
# plain :  CWbytearray(b'cf 8f f0 d3 57 c8 80 78 cc cc 90 b2 ba cd e0 26')
# plain :  CWbytearray(b'53 f8 cc f6 34 ba 1c 1e 62 ef 35 88 df 5b 36 42')
# plain :  CWbytearray(b'1c 2d b8 db 5c 75 61 e8 33 6f 97 c6 4b a0 30 c5')
# plain :  CWbytearray(b'c1 0a f8 47 c0 c6 3b 52 cf 06 8b ef de 3b 3d d3')
# plain :  CWbytearray(b'2b 9e f8 21 fd 15 4c a4 fa 65 11 4f 84 f4 4b a2')
# plain :  CWbytearray(b'df a8 d1 df a0 05 c3 e8 ce 58 3d 2a a8 c8 de b5')
# plain :  CWbytearray(b'68 ba fa 32 dc be e3 a1 24 a1 a9 cb ad 17 52 4c')
# plain :  CWbytearray(b'33 78 24 53 35 50 1d 95 af 6c 63 00 da dd e8 fe')
# plain :  CWbytearray(b'7d c1 32 8e 41 b7 2b c9 73 c8 76 4c 71 ca 18 50')
# plain :  CWbytearray(b'26 17 f1 91 ad b8 51 33 93 a3 19 d0 b4 3c 4e 44')
# plain :  CWbytearray(b'ec 2c 1f 12 12 74 8e be e0 d9 d1 6e 5b f9 8b 8d')
# plain :  CWbytearray(b'bb ae e0 47 f9 e2 79 76 19 71 e2 30 3c c7 06 ac')
# plain :  CWbytearray(b'94 bf 2e 66 3a cd 93 21 ca c2 85 b6 ad 93 20 56')
# plain :  CWbytearray(b'86 a1 c0 74 d2 9a e9 a2 5a c4 bb f9 b3 ac 58 e0')
# plain :  CWbytearray(b'65 45 48 32 8c ee 0b cf 4f 1e 99 28 67 e9 cf 14')
# plain :  CWbytearray(b'c8 bb 51 eb 24 1c 2d 7b b5 af 5c e7 a8 35 62 61')
# plain :  CWbytearray(b'9e 56 8a 16 6c e0 14 36 ff d4 5f 52 ef 82 a5 1c')
# plain :  CWbytearray(b'44 73 cf cd 78 f5 65 bd 89 13 a4 78 c8 f8 50 81')
# plain :  CWbytearray(b'ce b4 25 56 42 6e af 1d fa 91 bf 64 e9 26 23 8e')
# plain :  CWbytearray(b'83 0e 90 01 ca 77 bf 20 1f ca 87 a9 10 92 f8 f6')
# plain :  CWbytearray(b'5f 1f bb a4 83 37 ad e3 d5 14 7b 5f f4 ad 83 e5')
# plain :  CWbytearray(b'80 6d 1a ea 69 64 11 6f 8d ef b8 e9 2e c4 cc dd')
# plain :  CWbytearray(b'8e b9 a2 bc 91 e7 03 37 f1 43 bb d7 55 d8 1b cc')
# plain :  CWbytearray(b'68 52 de a6 0b 95 72 3e 3e 02 aa 47 57 66 77 0a')
# plain :  CWbytearray(b'7e a3 9e f4 28 c4 be 3e ba 6c 34 57 5c 0f e4 87')
# plain :  CWbytearray(b'36 2d 1f d7 93 3a b9 b0 bb 92 d5 dc 74 ce f9 94')
# plain :  CWbytearray(b'2a 25 a6 b9 86 0c ac 99 e9 ae be 7d 00 ee 96 11')
# plain :  CWbytearray(b'b5 43 7b 47 d4 00 1c d4 e8 cf de dd ce 28 88 24')
# plain :  CWbytearray(b'30 77 ef fc ec 2b a2 a2 86 1d d7 9b 50 68 24 f6')
# plain :  CWbytearray(b'b4 0a 68 f9 45 c6 9e e6 f8 af 56 12 f2 fd 9b 40')
# plain :  CWbytearray(b'dc ce ea 47 60 e2 0d f0 d8 3d 29 e1 59 5c 10 e8')
# plain :  CWbytearray(b'b6 3c b0 9a a3 8e 49 91 bd 3c 3e cf 5f 87 f9 a2')
# plain :  CWbytearray(b'4c f1 84 bb e2 1e 6d fb 84 76 e0 de 71 f8 e6 ba')
# plain :  CWbytearray(b'11 14 6c e9 03 bf 94 3f 6a 07 1a 21 96 2d e4 f2')
# plain :  CWbytearray(b'08 f7 5c b0 33 97 15 a2 1c 1c 6e fa 98 a8 a2 88')
# plain :  CWbytearray(b'08 5c 95 52 ae 6f 67 27 de 3a be b9 1f ed 10 99')
# plain :  CWbytearray(b'31 7c 7f fa e0 e0 60 ee 68 a4 e3 67 90 2f 02 ba')
# plain :  CWbytearray(b'cf 5e c9 26 11 b0 a2 55 40 6f 5a f1 76 40 b9 4c')
# plain :  CWbytearray(b'a9 b3 a1 33 a3 ae 45 97 39 ab ad c5 cc 01 22 42')
# plain :  CWbytearray(b'9c 44 6a ef 16 b0 c0 04 14 04 38 1f 16 1e d2 ab')
# plain :  CWbytearray(b'b4 b0 fc 7d aa 6d 27 e4 8d c1 dd b8 30 ad 55 50')
# plain :  CWbytearray(b'35 40 f2 e2 08 83 20 43 44 28 8d 04 e4 bc 23 d6')
# plain :  CWbytearray(b'af fb 67 e9 54 50 a6 f5 5b 8d e6 d8 54 3c 39 48')
# plain :  CWbytearray(b'04 0a de b7 e1 ab e8 8c 6d 14 af 51 9a 2e 66 ea')
# plain :  CWbytearray(b'60 f8 37 e8 de 86 2c 0f da e9 d2 c3 f0 b4 be cd')
# plain :  CWbytearray(b'1f 73 4b 98 f8 8f fc 3c 1d c1 57 01 27 ce 83 4b')
# plain :  CWbytearray(b'd9 e3 e8 06 a2 c8 4c b4 b8 40 74 36 df fe 76 5a')
# plain :  CWbytearray(b'47 b2 ee cc cc 76 da 17 45 aa 89 6d ed 5e 23 2e')
# plain :  CWbytearray(b'a8 85 dc e9 64 95 04 99 76 4d f3 3c 6d 2f e1 e5')
# plain :  CWbytearray(b'ec ea c2 37 1a a7 15 87 3d c7 44 63 61 db cd 58')
# plain :  CWbytearray(b'a8 79 c3 33 d9 74 58 b9 37 43 4e 12 ac dd ac 89')
# plain :  CWbytearray(b'ea f0 f6 f5 9f ab 28 af 24 ba 9d 2c bc cc e0 7b')
# plain :  CWbytearray(b'ca d9 f3 fc 16 29 9f 5a ea cf 2d ff ea cb 50 32')
# plain :  CWbytearray(b'6f 5d 92 0b e8 d7 f9 f1 8b 51 87 34 54 2c 26 a9')
# plain :  CWbytearray(b'4b 91 4a 0a 72 be 8a 0a ed 9e ba ed 72 88 ac d9')
# plain :  CWbytearray(b'62 3c a9 6d 41 4d e1 15 66 e7 a2 57 a9 1a a5 f3')
# plain :  CWbytearray(b'a3 40 de 7b c7 1e 63 6b d9 de a6 3f a1 ab 39 09')
# plain :  CWbytearray(b'8e e3 2e 57 df c1 46 ab d5 87 d3 2e 8a cf 73 a6')
# plain :  CWbytearray(b'71 50 fb eb b2 54 70 a4 44 b8 94 2e 51 cb f9 dd')
# plain :  CWbytearray(b'52 11 59 a4 c5 5f 1d 48 0c d6 9e 71 29 3a 80 51')
# plain :  CWbytearray(b'f1 59 f9 5a 40 d8 f6 dd 76 c3 7a 85 8a 72 3b 03')
# plain :  CWbytearray(b'9c ec eb 6c 7d 8f fa 7a 27 52 9d 05 1e 02 ff d6')
# plain :  CWbytearray(b'a5 ed fb ea 27 80 91 bf 45 6f e3 a1 2c ba b3 66')
# plain :  CWbytearray(b'41 46 3d 9e 05 86 6f 4c 1d 31 34 21 52 99 ae 94')
# plain :  CWbytearray(b'89 4f 34 b5 2d c3 7d fe 67 34 b0 08 f1 e1 b3 79')
# plain :  CWbytearray(b'25 47 48 83 fd 6f df 47 50 ed 6f 3c 54 f0 a5 d1')
# plain :  CWbytearray(b'b9 ab 40 2f 5c 47 a3 24 68 25 8f 2a 47 89 56 a1')
# plain :  CWbytearray(b'd9 38 72 06 c3 e4 54 a9 a6 30 df 8e c9 42 06 07')
# plain :  CWbytearray(b'4b 25 a2 d9 14 b4 dc aa 8b 95 4b a2 10 88 10 98')
# plain :  CWbytearray(b'9a eb 72 f8 10 bf 85 f8 89 cc 87 54 8a 8d 0b c5')
# plain :  CWbytearray(b'82 fc 1a 9b 70 e2 77 87 fc 43 b1 64 0b 6c 58 82')
# plain :  CWbytearray(b'b5 1c b8 a2 c8 1e 45 a3 97 ab 95 62 10 96 c0 4e')
# plain :  CWbytearray(b'9b 6e b0 f7 78 b1 f7 62 2c 1b cc e9 a8 7e d9 52')
# plain :  CWbytearray(b'a7 3a fc a5 c6 e4 e8 d8 16 94 d2 02 0e c6 41 98')
# plain :  CWbytearray(b'a2 5b 17 d8 f5 ec 6a 67 66 a1 64 2e 63 2a 8a 6c')
# plain :  CWbytearray(b'8b 20 ac 2f d1 e3 da d1 b0 d1 09 6b 66 fc c9 ba')
# plain :  CWbytearray(b'5b 89 8a 48 92 82 21 44 ed 09 c5 f5 2a a2 34 d2')
# plain :  CWbytearray(b'01 40 7e 9f 8a 52 9d fd e4 37 74 a4 9d f9 7e 32')
# plain :  CWbytearray(b'd0 fc c7 57 67 41 f7 bb e2 fb 4b 6d 8c a1 37 60')
# plain :  CWbytearray(b'84 e8 16 45 c6 07 54 20 35 20 20 40 91 df 1f de')
# plain :  CWbytearray(b'71 7a 37 06 11 a4 c6 ee 75 f3 22 ef d5 ae 32 fa')
# plain :  CWbytearray(b'b9 e8 50 4e 6a 04 e5 c0 25 53 76 9a 0e 84 ec 9d')
# plain :  CWbytearray(b'1e 57 ad bb 57 1d e9 45 54 e1 b5 74 c8 3f 40 61')
# plain :  CWbytearray(b'9e 52 32 62 7e c8 4b f0 c4 b9 10 90 90 87 1b a8')
# plain :  CWbytearray(b'05 fe 23 84 87 8c dd 1b 2c 80 b0 28 e8 35 1b 12')
# plain :  CWbytearray(b'b5 86 b6 38 85 31 da f7 b6 38 dc 6d 37 94 96 5d')
# plain :  CWbytearray(b'cc 0b 08 18 64 d2 75 87 2c 5a 56 b2 f5 ae 7d a9')
# plain :  CWbytearray(b'9e 3d 42 6d df 52 e5 bb c9 8b b6 40 f7 62 4f 39')
# plain :  CWbytearray(b'fd 51 c9 eb e0 52 91 98 68 21 ab 18 79 46 24 be')
# plain :  CWbytearray(b'ec 4a 7a b3 17 ce 5b 42 1c 60 45 ec 19 14 a5 8f')
# plain :  CWbytearray(b'02 77 76 66 f6 30 96 95 87 1b 53 ae 6b 53 6f b9')
# plain :  CWbytearray(b'b5 5e f1 a0 60 4a ff 90 7d d3 f4 99 1b b7 f7 a0')
# plain :  CWbytearray(b'fd 6d f2 d6 ac 2e d1 f5 a6 61 b3 9f 30 6b df 03')
# plain :  CWbytearray(b'f6 70 e8 5c 0a 36 fa ae 33 e5 30 ee 6b 4b 45 e5')
# plain :  CWbytearray(b'25 ef 02 6b 1e 64 b8 13 0c 82 6f 00 fd 7d 57 9f')
# plain :  CWbytearray(b'78 07 c3 23 c7 98 16 24 08 90 5d e5 ff e9 14 9a')
# plain :  CWbytearray(b'ae 70 77 ba 2b 28 a1 08 56 c4 37 db ae 23 af 0b')
# plain :  CWbytearray(b'86 30 91 11 06 8b de 64 5c 2a 16 a5 72 5a 68 55')
# plain :  CWbytearray(b'7c 21 a2 e7 3b b1 f0 5e 86 e1 1f a1 d7 1e 62 98')
# plain :  CWbytearray(b'85 f1 9c d3 1a d3 ff a8 f8 f4 4d 37 3f ef 07 9e')
# plain :  CWbytearray(b'22 c2 58 52 3d a9 24 9d 30 a1 e7 e0 aa 8f f7 25')
# plain :  CWbytearray(b'3e 63 a2 c1 49 49 6a 25 0f 82 26 5e 28 73 ab c9')
# plain :  CWbytearray(b'94 46 af 2d 61 bd b1 9f 50 30 0e 3b 51 c9 9f f5')
# plain :  CWbytearray(b'a9 04 46 e6 1a 61 68 ad a5 ee cd b1 8a cc fd fb')
# plain :  CWbytearray(b'84 e7 5c 2a c6 90 75 4c 13 ce eb 7e 67 a8 54 60')
# plain :  CWbytearray(b'71 44 16 49 f8 6b e5 d1 04 37 4f b8 6e 50 ee 41')
# plain :  CWbytearray(b'2e b6 67 81 a0 65 e9 35 43 1e be 86 d4 d7 cb 47')
# plain :  CWbytearray(b'd3 32 a6 93 5f 8d 23 fb 86 c9 2d 4a bd 3f 0a 94')
# plain :  CWbytearray(b'07 d7 57 e7 dd 4a 93 e1 30 0c 70 e7 27 2d ef d1')
# plain :  CWbytearray(b'61 bc ec e8 f3 3b 51 67 a5 98 08 54 56 6d ed 61')
# plain :  CWbytearray(b'58 c8 2c 02 e3 55 44 f6 72 21 f6 2c 1a e7 41 69')
# plain :  CWbytearray(b'6c c4 88 17 51 25 19 ef 5a b6 18 e2 34 a4 fb 7a')
# plain :  CWbytearray(b'ca fe 50 a7 15 85 a0 b7 60 34 ce 1b 6f 5c 23 61')
# plain :  CWbytearray(b'25 af 04 c9 1a c1 96 9c 47 e5 83 11 67 66 df 24')
# plain :  CWbytearray(b'8a 97 bf a7 15 64 20 c5 44 0b fd 3a d5 bd 0f 41')
# plain :  CWbytearray(b'36 7a ec c9 37 43 2b 82 2f e6 2b 3c 51 4a 8c b5')
# plain :  CWbytearray(b'74 8a 3a 49 2f d5 8c 05 aa 27 5e 2a b1 c5 3f f1')
# plain :  CWbytearray(b'1e 9c 5f 48 54 1b ab ba 14 bf 02 a0 7e 73 67 b1')
# plain :  CWbytearray(b'68 f5 4a a7 2f 96 e7 a2 36 78 4d 06 91 01 c1 36')
# plain :  CWbytearray(b'6e 97 02 ac d1 eb 1a 31 17 8c b4 5d 6d b9 12 85')
# plain :  CWbytearray(b'82 ac bb 0e 0b 6e 2b 4b 8d 22 e1 c0 89 a5 cc ae')
# plain :  CWbytearray(b'f7 a2 de 1a 43 36 80 00 16 fb ec c1 b7 49 e0 17')
# plain :  CWbytearray(b'd3 f5 f4 d1 b6 43 8c 8b 3c 23 d0 0d 84 51 a2 27')
# plain :  CWbytearray(b'93 25 10 2b db 77 88 fa f3 2e 10 7a fb eb f4 87')
# plain :  CWbytearray(b'd9 69 7f 5d 43 cc 74 4c 7a 92 df 94 02 44 65 68')
# plain :  CWbytearray(b'dd ee b5 53 24 23 80 eb 7b 0d 24 6b c1 a3 2e 8f')
# plain :  CWbytearray(b'cf 69 b1 84 37 16 7a a9 79 b9 47 6a d9 8a de 92')
# plain :  CWbytearray(b'80 79 30 f3 2b 24 9e b9 59 86 ab c9 00 cb db af')
# plain :  CWbytearray(b'52 74 9c e9 73 4f 91 ac 88 0a 09 ae 17 2a 1d ff')
# plain :  CWbytearray(b'71 b2 c1 67 6a aa 6f 51 30 89 e9 c0 d2 0d ae 52')
# plain :  CWbytearray(b'52 35 92 46 2e 3d 2c 36 4f 38 27 e5 96 a5 51 4a')
# plain :  CWbytearray(b'fe 5c 30 6a a8 6e 05 b7 13 e9 50 f4 b3 ba 7a e2')
# plain :  CWbytearray(b'61 cb d9 5d 47 cd 50 22 0f 7b 9b 13 a7 53 5b cf')
# plain :  CWbytearray(b'fb 46 ee 65 03 cd 21 15 ba e9 ce 79 92 4f d5 99')
# plain :  CWbytearray(b'14 c1 7e 7e ae 94 d7 f7 b9 47 94 7f 7b 00 e0 fb')
# plain :  CWbytearray(b'06 08 dc 35 62 8e ed 31 9a de 10 7c fe b1 6c 27')
# plain :  CWbytearray(b'e3 9f 2c d5 28 03 63 93 b5 7a af 86 b6 7e 6c 46')
# plain :  CWbytearray(b'ac c5 45 06 5f 53 6e 3d f4 e2 35 c8 e1 14 eb 6b')
# plain :  CWbytearray(b'fc a0 6c bd 9a 40 37 83 50 5f 7c 19 b6 3e ed 4a')
# plain :  CWbytearray(b'58 02 13 7b 34 ab 1b cf e1 0c d7 ca 8a 6a bd bf')
# plain :  CWbytearray(b'ce 04 c9 58 60 ce ab 79 71 c0 18 d6 19 f6 cc 7c')
# plain :  CWbytearray(b'87 68 e2 b4 c1 da 1b cc 21 d9 70 63 9a ee f7 fe')
# plain :  CWbytearray(b'3d 7c d0 43 c5 e9 f0 36 e1 ff e6 50 39 e4 a5 cf')
# plain :  CWbytearray(b'fb 38 46 36 b4 24 bb 38 27 fc cd cc fc 17 04 2e')
# plain :  CWbytearray(b'66 6b 3e d4 c4 80 66 44 a3 a8 f0 3a 37 e4 ea 18')
# plain :  CWbytearray(b'9e 63 52 89 e0 49 42 2d f7 f3 31 a4 5f 37 f6 8a')
# plain :  CWbytearray(b'b0 77 10 7a eb 8a f8 54 e0 a8 f3 86 bd a0 8a a2')
# plain :  CWbytearray(b'2c 46 50 43 ff 12 79 70 50 79 9b fd 36 56 31 17')
# plain :  CWbytearray(b'cd fe 91 c7 6d 99 a3 1e 91 60 63 d2 1e b9 08 db')
# plain :  CWbytearray(b'38 65 99 2a 36 45 a3 8c fd 14 b0 7e 30 8e 30 fd')
# plain :  CWbytearray(b'23 4a b8 ff 36 a3 ea ae 57 0d f9 34 f5 6a b3 86')
# plain :  CWbytearray(b'ff 89 0c a1 e1 b4 63 af a4 65 96 38 a5 c9 a1 97')
# plain :  CWbytearray(b'6f 3f 66 58 cd 51 cd fd 17 ca 56 9b c6 ee 4b 51')
# plain :  CWbytearray(b'd3 fd cf c2 fd 5a ec 8c 18 c1 81 92 c5 92 a7 66')
# plain :  CWbytearray(b'6b 1a 21 78 48 88 fb 03 95 47 1e b1 fc 57 ec 46')
# plain :  CWbytearray(b'd2 c9 e0 20 76 b9 ea 24 45 86 12 23 e5 1a 5a 83')
# plain :  CWbytearray(b'03 ea 5f e9 0d 08 81 3a 01 d3 10 e6 82 de 4c 46')
# plain :  CWbytearray(b'af 66 bc f5 3b 4c 60 4f 8d 8a 02 d5 f1 15 69 fe')
# plain :  CWbytearray(b'82 4a 8a 68 48 1b b0 86 50 df 93 45 e1 8d 2e f5')
# plain :  CWbytearray(b'4a bf 3f e2 46 9a 10 62 60 ef 49 b9 38 fb 24 89')
# plain :  CWbytearray(b'5b 7a 63 72 7c 23 5b c6 27 3b d6 27 0a e4 60 35')
# plain :  CWbytearray(b'b7 22 95 fc c6 66 d9 ad 89 06 84 6b a4 66 1f 46')
# plain :  CWbytearray(b'e1 89 06 06 28 59 1b ec 7a 62 0f fe 61 7f ae 40')
# plain :  CWbytearray(b'31 9c b1 16 2e ae 87 97 f0 af 27 bf 77 df a1 48')
# plain :  CWbytearray(b'65 53 2a a3 fc 61 1a d3 16 83 05 d9 10 f5 7e 32')
# plain :  CWbytearray(b'7a 00 30 ac f6 6e ec 1e 63 d0 f8 53 4e 89 02 70')
# plain :  CWbytearray(b'3b b6 ef 6c d4 7c da f6 26 a3 be 14 1c 04 1a 0b')
# plain :  CWbytearray(b'1b 18 0d 93 46 04 ee 36 b2 b5 55 4e 1b 9b f2 27')
# plain :  CWbytearray(b'2b d1 e9 8f 53 8f 01 a3 14 f5 16 36 c0 65 d2 3e')
# plain :  CWbytearray(b'44 b4 9c 2b e2 41 cc 9a 97 60 ac 61 a3 bb 30 1c')
# plain :  CWbytearray(b'c0 a2 34 cd 1e 4b 01 37 9c 1d 94 ce e0 bd 03 58')
# plain :  CWbytearray(b'ce 23 1c 50 23 02 ac b9 98 f6 e3 c8 23 c7 a5 2c')
# plain :  CWbytearray(b'bb e2 48 67 c7 7b 1b 7b b3 dc 28 03 66 9a d1 e3')
# plain :  CWbytearray(b'03 d2 d8 12 4c 31 0b e2 88 07 b4 f9 ff f8 99 fb')
# plain :  CWbytearray(b'8d a8 8a 83 d6 d7 9d 49 30 59 f4 87 02 78 63 ba')
# plain :  CWbytearray(b'70 eb 2f cd 03 f3 d2 cf 4c 2a 39 9e 66 76 e9 2e')
# plain :  CWbytearray(b'61 b1 c2 99 f7 37 24 bc 73 03 2b 71 04 ac 7e b1')
# plain :  CWbytearray(b'71 63 3b b4 60 b5 51 6e f5 93 ec b3 89 33 05 94')
# plain :  CWbytearray(b'd0 c1 a4 12 56 c3 be 6c 5b d5 94 c5 98 a5 61 32')
# plain :  CWbytearray(b'2f 8c 4c 74 88 d3 94 e4 41 8d 36 5f 90 f5 cf 92')
# plain :  CWbytearray(b'ef d7 11 fa 00 46 84 c4 cd 6d 5a 1c 67 47 26 af')
# plain :  CWbytearray(b'74 21 6e e5 7c 3e 80 ee 61 d7 b9 9c 79 f9 b1 d0')
# plain :  CWbytearray(b'4a ac b8 39 dc 52 1f 87 19 c1 d9 c1 fd 1d 8b 3a')
# plain :  CWbytearray(b'0c e2 5c 30 6a 69 a3 c2 4f 56 9e 95 5e 3e 1c 8a')
# plain :  CWbytearray(b'd8 a4 c8 58 e9 81 0d c3 6a 93 50 29 be cd d0 03')
# plain :  CWbytearray(b'e3 de b7 d0 61 e9 a1 dd 8b fd 4b 42 38 66 88 02')
# plain :  CWbytearray(b'c4 dd 86 cc ad 7c df 20 91 ed 3a b4 3c 40 12 95')
# plain :  CWbytearray(b'99 35 cc 9b 4c 8c 5d c6 f0 ce 58 8e 30 8b 77 07')
# plain :  CWbytearray(b'60 1a f3 83 fd 05 bb 2f 5e 65 f5 20 c9 63 ab 2a')
# plain :  CWbytearray(b'1c 83 78 e3 dd 48 7d 8a d7 ed ca 76 4e 28 e9 1b')
# plain :  CWbytearray(b'3f 19 e6 6b f7 dc dd d7 7a 28 73 10 90 1f 58 ae')
# plain :  CWbytearray(b'33 bd 06 81 36 46 03 07 dd 36 da ec a1 ef e3 f6')
# plain :  CWbytearray(b'ff 54 e4 55 3c 71 c3 08 c9 6d ea b6 7b 5c 1b c3')
# plain :  CWbytearray(b'13 ac 9b e2 df 65 16 b1 39 08 83 c3 36 ad 9a 40')
# plain :  CWbytearray(b'7f c2 32 62 53 6d cd d3 ac 73 1b c2 79 8b 64 e7')
# plain :  CWbytearray(b'18 d9 43 35 3f c5 e7 5b 01 7c 21 e5 33 cd e6 f6')
# plain :  CWbytearray(b'c3 34 9b cf 0c 4d 9d 57 1b 2f c2 d1 a2 86 f5 a9')
# plain :  CWbytearray(b'b5 6e 95 13 bb 1d b0 bc 49 f4 6c 7c 1b 93 b2 2b')
# plain :  CWbytearray(b'8a 21 95 a1 14 c3 07 cd 4a 45 4a a7 54 8c 3f 97')
# plain :  CWbytearray(b'f8 94 3d 11 3e 83 37 4f a6 91 0c 0f d3 e0 b5 4d')
# plain :  CWbytearray(b'0b dc f8 de 11 aa c3 31 c5 28 6b 13 34 db 63 a5')
# plain :  CWbytearray(b'e1 02 a4 94 45 0b 1d 14 22 9c 38 ae 01 46 7a 21')
# plain :  CWbytearray(b'2b 1f de ed 7e 94 2c 95 be c5 75 b0 d4 e7 e6 8d')
# plain :  CWbytearray(b'88 fe b7 08 c2 bf 16 56 4b 37 f3 58 ff 1b 0d ce')
# plain :  CWbytearray(b'03 c0 39 dc fb 2c 19 67 22 56 3a f2 71 df 9a 73')
# plain :  CWbytearray(b'ad 8e 5f 36 81 8d 48 1f c5 fb 4c a8 53 62 21 8a')
# plain :  CWbytearray(b'ac 7c 56 40 72 f3 52 21 e6 1c f7 52 d9 34 6a e3')
# plain :  CWbytearray(b'f7 c7 f6 b9 f1 c0 bc 5d 95 81 e5 d7 72 26 eb fc')
# plain :  CWbytearray(b'9b 2e 23 64 d5 9a 2d 84 59 34 1e 48 50 1a 78 5f')
# plain :  CWbytearray(b'0d 2c a1 cd 94 ff b0 2a f7 cc a1 89 b7 04 42 81')
# plain :  CWbytearray(b'4d 30 91 b1 c8 1f fc 52 d1 80 d7 2f 3f 41 04 58')
# plain :  CWbytearray(b'16 73 68 bb 8f fc 19 34 65 47 e9 2a 3c e8 fa f0')
# plain :  CWbytearray(b'82 4f 87 18 2c 73 5f 71 7a a5 f1 05 67 10 d4 55')
# plain :  CWbytearray(b'9c ea b4 0b 4d 23 dd 0f 6a a9 b3 6f 83 41 d6 f6')
# plain :  CWbytearray(b'6b 67 fa aa 4f e2 1b dd 38 a4 85 e4 71 b8 4e ef')
# plain :  CWbytearray(b'3d 18 7a 7f d8 42 f4 a9 6e e9 f9 fa f6 5a 02 66')
# plain :  CWbytearray(b'94 cc c1 8a 4b 48 63 80 6e 7d 44 9e b1 36 4f d5')
# plain :  CWbytearray(b'fb a5 4a 88 21 17 c5 05 31 81 a3 00 a8 3f 1a 92')
# plain :  CWbytearray(b'11 9b ee c0 4a fc f9 e0 8a 9a 8d ab 15 41 e2 10')
# plain :  CWbytearray(b'3f 46 51 5e 25 e6 f8 5b 24 98 79 71 9d a8 fd 39')
# plain :  CWbytearray(b'18 74 c5 b2 69 0e fa 45 0c 25 92 ab 34 31 1c 9f')
# plain :  CWbytearray(b'bb 16 be d1 25 a5 2f d7 0b 8b fa f6 c3 43 ec 8f')
# plain :  CWbytearray(b'8b 27 a4 e9 63 1b df 67 7b c0 44 84 d8 78 46 75')
# plain :  CWbytearray(b'0b 88 e9 0e ed 3b cc 7f 39 84 58 fc 9b fe ab 22')
# plain :  CWbytearray(b'fa 5b c6 84 9f 64 57 70 35 cb ee 38 a5 95 94 9d')
# plain :  CWbytearray(b'cd 2b eb 13 f3 42 49 ba 2f e6 05 67 1a a5 37 0a')
# plain :  CWbytearray(b'69 bf 4c d3 87 d4 09 9f 0e 8e c1 e5 30 2b 2e b6')
# plain :  CWbytearray(b'ad 03 87 5c 3e d3 45 71 a5 c8 a6 18 0c 50 60 73')
# plain :  CWbytearray(b'ad 86 8c af 5b d4 2e ee 49 b0 aa 08 54 9a 03 73')
# plain :  CWbytearray(b'7c ab 5b f2 40 7a 16 2b 6f 48 aa e1 97 be 06 3f')
# plain :  CWbytearray(b'b3 61 00 7c a7 93 6d ce f5 51 75 ac 24 46 e7 3b')
# plain :  CWbytearray(b'61 1a 3e bd 51 4d 5a d3 ec 93 34 1c 03 41 15 72')
# plain :  CWbytearray(b'78 9e 40 39 d6 3c c6 44 dc 21 f9 3c 46 5d 0c e8')
# plain :  CWbytearray(b'53 24 6a 01 fa 66 2d cf 02 8b a8 73 c7 f7 3f 89')
# plain :  CWbytearray(b'84 ca 18 71 1f 20 8c 3b 2e 8f 1e 3d 49 b2 96 f8')
# plain :  CWbytearray(b'5f 9a 68 06 c3 f9 bd 8c 5b 7b d2 bd 64 f5 b3 38')
# plain :  CWbytearray(b'03 43 e4 03 4c 78 ce 2c 9f cc 10 78 bf 25 ed f3')
# plain :  CWbytearray(b'e4 dd 79 b2 d4 e8 4d c0 5c 12 be 30 06 88 8a 15')
# plain :  CWbytearray(b'fb 75 ba 99 55 75 f8 d7 e4 20 3a f8 e7 01 b3 18')
# plain :  CWbytearray(b'19 ac 19 05 04 91 90 c4 4f 65 5b 40 7c 6e cc 32')
# plain :  CWbytearray(b'df 1a 79 e9 c6 a8 56 2c 36 d5 b6 6d b2 1f 6d b0')
# plain :  CWbytearray(b'66 92 0d 6c d8 9a 80 da a5 9f 90 91 a6 de 1e e5')
# plain :  CWbytearray(b'87 9a ed ca 14 b8 e1 fe 7e 74 8e b4 ab fa d9 a6')
# plain :  CWbytearray(b'1c 58 61 ed b3 fa b3 b9 f9 9f c7 8c 23 3c 9b b5')
# plain :  CWbytearray(b'24 52 70 cd 62 7e 0e 16 15 2e 30 b5 fd 97 3f 56')
# plain :  CWbytearray(b'68 55 29 38 e3 df 27 a5 17 21 cc ae 55 eb 2a 1a')
# plain :  CWbytearray(b'05 fc a3 e4 58 9c 25 20 52 5c dc 42 de 6f 66 67')
# plain :  CWbytearray(b'3e eb d9 c9 f3 e9 07 89 18 09 f6 ce dd bd e4 94')
# plain :  CWbytearray(b'24 ea 47 89 84 62 cb bc 81 14 b7 db 73 7e 29 57')
# plain :  CWbytearray(b'33 17 83 e0 23 96 4d fb da 15 a6 43 78 80 40 da')
# plain :  CWbytearray(b'52 bf fe 24 48 40 e9 b3 c8 28 92 0a 15 ea 0d 9e')
# plain :  CWbytearray(b'24 fa e0 00 e0 a8 c8 b0 96 4d ae 76 c6 5d 12 15')
# plain :  CWbytearray(b'8b bb 94 e2 4a 9e d0 a2 b4 3a a2 e5 d1 90 16 1d')
# plain :  CWbytearray(b'2d c9 c6 12 f7 23 f1 1c 0e 41 fa 86 04 57 26 c7')
# plain :  CWbytearray(b'4e ad 25 f6 90 08 c3 8e 50 61 c1 7b 91 27 b8 74')
# plain :  CWbytearray(b'cf 2d b4 5f d9 25 5b e1 ce 81 06 9d 11 25 90 76')
# plain :  CWbytearray(b'3c 74 24 ae 88 a1 bd 4e 06 84 a8 b4 7d 61 07 be')
# plain :  CWbytearray(b'23 05 3f 67 ff 09 ef 62 7e 63 e0 6f 05 95 b7 87')
# plain :  CWbytearray(b'97 50 e3 e1 a1 72 91 1b bb 65 9f c1 b3 1d 23 70')
# plain :  CWbytearray(b'69 76 b9 fd 6d af db 1d a0 5a a3 69 9d 88 c9 39')
# plain :  CWbytearray(b'6c 2f 3e 4c 35 ef 98 27 5a 59 c7 f9 ee 9c 5b 81')
# plain :  CWbytearray(b'02 77 57 9e 98 11 4d 57 f6 5f a3 c9 41 9e cc b8')
# plain :  CWbytearray(b'c5 b5 70 b1 a0 86 be 03 01 09 56 8a 20 e6 ce a8')
# plain :  CWbytearray(b'c8 21 a2 ef bb de 44 30 47 d7 f3 17 3a e2 4d e6')
# plain :  CWbytearray(b'ec a9 ff 23 55 bd 05 82 04 24 bf c5 8a 84 95 af')
# plain :  CWbytearray(b'5b 0f 20 87 70 39 71 c4 44 7e 5a a2 78 90 49 92')
# plain :  CWbytearray(b'30 75 03 ae 7f 0b af 31 61 f2 cc a4 64 38 78 ba')
# plain :  CWbytearray(b'79 b4 0c da 3b 99 6d 4f f6 67 01 26 38 b6 82 c0')
# plain :  CWbytearray(b'c4 7b 55 0e 35 7f bf 31 83 4e 1f f0 5d c6 ff d9')
# plain :  CWbytearray(b'db ce 94 0e 72 26 4e 2d ba 9c 7e b3 ab 9a fa aa')
# plain :  CWbytearray(b'8c 7e d3 2e 37 61 f4 91 d5 b1 d3 2d 84 09 aa 5a')
# plain :  CWbytearray(b'cd 38 dd 9e dc e1 6d 0d 65 c9 3e da f1 ea 32 6a')
# plain :  CWbytearray(b'8d 65 05 46 af bb 8b 2d 90 fb 10 45 16 50 37 b7')
# plain :  CWbytearray(b'a4 26 a7 94 ef b6 50 a7 bc dd c1 2d 7f 77 6b 47')
# plain :  CWbytearray(b'5b ee f6 5e da ee 85 0e 2b 4a 07 36 3e eb 12 44')
# plain :  CWbytearray(b'd3 89 b8 5d 2e 01 00 3f 7d d2 6a 33 20 ab a8 b0')
# plain :  CWbytearray(b'b5 92 2a 32 49 0c 0d b1 cb a0 c0 aa 3b 59 3c d6')
# plain :  CWbytearray(b'3c f4 f9 05 11 59 35 20 93 9e e7 f9 16 1c 6a f7')
# plain :  CWbytearray(b'2b b8 4a f4 d7 ad b2 4b c5 f0 74 0d f2 cb ee 56')
# plain :  CWbytearray(b'5d 5c 23 6d 9a ca f3 05 06 0c 64 06 78 47 ff d9')
# plain :  CWbytearray(b'93 25 24 46 45 13 97 d8 4a 2a c6 d6 46 d6 69 23')
# plain :  CWbytearray(b'e1 aa 1f cf d0 ae 4a e7 07 1b 85 66 4a 1e 61 ca')
# plain :  CWbytearray(b'56 7f 5f b3 a3 91 1f 48 97 ec e8 92 ec 7a dd 92')
# plain :  CWbytearray(b'ea 50 64 92 14 47 74 7a 7f 5b e6 0b e0 2d 78 a8')
# plain :  CWbytearray(b'e4 9b 6a 18 db 42 0d 1f 13 41 99 84 8e 46 7b 03')
# plain :  CWbytearray(b'aa e2 d6 83 28 3b 10 c8 a5 15 de 87 72 4a cb 95')
# plain :  CWbytearray(b'd2 2b b0 68 49 a5 77 27 5c de 0e ad e9 27 66 73')
# plain :  CWbytearray(b'e9 18 ef 43 72 f8 c6 54 ec 64 74 0b f8 79 fc 32')
# plain :  CWbytearray(b'3c bd 4c 1e 97 e0 37 59 28 e0 6e 55 fe 11 6c 49')
# plain :  CWbytearray(b'c1 01 7b ef af 07 d5 81 ff 24 b5 59 08 e6 8d 6f')
# plain :  CWbytearray(b'c2 1d ba 3c c9 e0 5f 91 99 7a fb 59 1f 6f 05 ed')
# plain :  CWbytearray(b'72 2c a8 bc e5 23 c5 89 48 bc cd 1f 91 d3 c9 56')
# plain :  CWbytearray(b'15 4d 8c 7c c7 87 37 98 16 20 60 8d a1 34 9f 93')
# plain :  CWbytearray(b'fa 02 cc 27 9b 60 d0 c7 23 12 76 7a 63 d2 de 7e')
# plain :  CWbytearray(b'70 01 da 9c 69 a4 79 66 3c 25 a0 24 81 5a 2b 27')
# plain :  CWbytearray(b'7c 19 23 c3 ac 68 86 79 7a 9e 21 f4 5e 99 09 7d')
# plain :  CWbytearray(b'4d 51 2d ba 64 98 84 b3 bc b8 4b fd bc a5 56 11')
# plain :  CWbytearray(b'02 83 cc 63 ed ec 17 86 47 b9 b3 6b 44 44 96 df')
# plain :  CWbytearray(b'08 c8 3a 12 06 5b c2 9e 0e a9 b2 4f cf 8d 49 3a')
# plain :  CWbytearray(b'3c a8 27 d1 32 50 79 0e 99 70 14 34 73 94 ec 4d')
# plain :  CWbytearray(b'99 77 d3 e2 68 d0 b3 6a 86 90 65 5f 1d 6e 6f ac')
# plain :  CWbytearray(b'e0 47 bb bb 83 96 9f 8d 78 07 ab 23 44 33 d0 4b')
# plain :  CWbytearray(b'02 69 97 e0 92 0e 6d 8f f0 97 be a6 88 4c 50 3a')
# plain :  CWbytearray(b'c4 e8 19 d8 da 9f 72 76 cb a9 a1 01 42 c9 0d 64')
# plain :  CWbytearray(b'b9 f2 30 c4 e7 a4 e7 81 73 91 ef 4f e2 68 81 af')
# plain :  CWbytearray(b'08 1b d0 15 1a 46 cf 82 30 e4 c5 87 cd 54 b0 cd')
# plain :  CWbytearray(b'be b5 6d c2 b8 40 76 09 eb 37 8d 05 7b d6 96 12')
# ...
# plain :  CWbytearray(b'1e 2f 98 66 72 a8 fd 7a c9 5f 19 50 96 d3 95 d5')
# plain :  CWbytearray(b'ea e2 53 84 25 09 15 a0 96 a1 a4 f7 29 0a 1e d0')
# plain :  CWbytearray(b'ae a7 79 db 83 f1 c1 74 8e 5e 5f 81 ce 4b f4 38')
# plain :  CWbytearray(b'5f 68 98 ef ca 8d de 05 f4 45 26 58 67 54 f4 6f')
# plain :  CWbytearray(b'06 e9 4b 7d 0a 99 2e c0 da ec 10 f7 e3 90 8e ad')
# plain :  CWbytearray(b'8a e5 0f 9a 4b 15 ed 81 c0 a2 90 b8 d5 ab 5c 19')
# plain :  CWbytearray(b'7e d4 49 d1 25 e1 3f 42 70 ea d5 ae 38 59 25 70')
# plain :  CWbytearray(b'19 84 1a 7a 35 a6 11 e0 47 3a 4a f1 83 a2 41 62')
# plain :  CWbytearray(b'd5 b0 6a cf 21 82 d5 f7 37 68 e6 ef 60 4e 73 47')
# plain :  CWbytearray(b'53 d3 61 5c e7 50 a6 ac 8a 99 d9 f2 5e 40 8c 4b')
# plain :  CWbytearray(b'd4 8c c0 4e 0a ec de 6e 8b 77 be 53 f8 c7 e4 97')
# plain :  CWbytearray(b'37 a8 62 1d 50 b8 de c8 e0 6f 9c f8 41 cb 2f f6')
# plain :  CWbytearray(b'81 8b 59 c9 a2 69 14 76 39 27 3a 09 6a 47 7c f5')
# plain :  CWbytearray(b'2c 89 f0 b0 7b 06 45 5d 4a b9 42 a2 1c e8 c7 b2')
# plain :  CWbytearray(b'8f 8f 60 4e e8 de b5 82 11 67 84 54 cf 16 70 2b')
# plain :  CWbytearray(b'26 1c 9e 72 e4 84 87 7a 60 39 28 e2 24 7a 54 a0')
# plain :  CWbytearray(b'e5 81 59 06 ea 95 29 91 41 6c 62 f6 03 ed 58 be')
# plain :  CWbytearray(b'57 5b bf 07 f9 e6 b7 f9 37 3e 61 55 32 b6 0e bb')
# plain :  CWbytearray(b'06 a6 ae ec 36 24 ec 49 6b d8 f2 69 4d 97 f9 67')
# plain :  CWbytearray(b'6f 65 ad e3 65 40 2e b2 3a 16 16 06 62 9d e6 8f')
# plain :  CWbytearray(b'c6 4a 04 39 f7 31 22 bd 05 d9 53 31 dc 85 b7 51')
# plain :  CWbytearray(b'c5 4f db a0 77 ea cf 3d 43 bf 53 bc 99 3f ff 16')
# plain :  CWbytearray(b'27 cf 7d 86 44 ce be 96 c7 3e 2a 66 c8 84 6c dc')
# plain :  CWbytearray(b'd3 1a dd f7 e1 c8 b7 4f 0c 92 93 f8 57 42 d9 53')
# plain :  CWbytearray(b'af 18 62 8b 71 2c 4f e5 58 3d 61 73 80 07 9e 5e')
# plain :  CWbytearray(b'4b af a1 01 17 e2 bd 49 64 22 89 96 6d b2 cb 37')
# plain :  CWbytearray(b'1f 2f 50 53 70 9e 53 30 c8 97 c9 c9 a1 bb 5c e9')
# plain :  CWbytearray(b'86 68 5c 65 bc ca 2d 0d b3 eb bd 88 98 d6 ae ac')
# plain :  CWbytearray(b'83 36 7a ca be 84 c7 a4 95 2e 54 7f b9 ec 34 e2')
# plain :  CWbytearray(b'fc 63 13 0a 51 c1 c5 3a 03 0d 67 e0 2f 1a 7d c6')
# plain :  CWbytearray(b'f7 70 12 5b e1 63 f6 c9 83 e7 42 b0 f4 15 39 8a')
# plain :  CWbytearray(b'75 ba 85 f3 91 2f d3 12 71 40 58 77 9f c5 40 d6')
# plain :  CWbytearray(b'e9 a4 b4 65 13 d7 a3 0c 2d 88 b0 9b 09 92 8e 18')
# plain :  CWbytearray(b'd5 73 0a 30 8a c1 83 28 33 b8 19 dc b5 1d 9a ef')
# plain :  CWbytearray(b'c5 71 4c b9 68 f8 5f af a1 b1 ae 7b 2b 72 af 75')
# plain :  CWbytearray(b'99 a8 2d 41 bf 1b a1 3e f3 f4 22 0e 8a cb 03 3e')
# plain :  CWbytearray(b'bc 44 92 bd b0 4d c2 15 14 50 f2 f8 c0 eb 04 32')
# plain :  CWbytearray(b'64 e4 b7 87 7e 5d 7a 79 23 68 48 dc e8 57 1a 7a')
# plain :  CWbytearray(b'93 8a 9a 89 4c bf cc f4 9c 3b 6a 20 8a 95 fe 6b')
# plain :  CWbytearray(b'c7 ae d1 20 83 f7 99 58 e4 08 a1 0d 75 5e f3 43')
# plain :  CWbytearray(b'12 aa eb c7 ff 1a af b4 b6 a6 b7 5e 9f 93 1d 6a')
# plain :  CWbytearray(b'ab 97 7a 7f a5 d9 2c fe 62 40 06 07 90 73 ff b2')
# plain :  CWbytearray(b'fc 38 54 38 48 95 53 75 60 5b b6 a2 7f 1e f1 9e')
# plain :  CWbytearray(b'1b 60 ca 14 be 69 e1 42 27 df 94 53 b5 51 50 bd')
# plain :  CWbytearray(b'0f 1d 41 28 4e 0f 6e 52 f6 10 85 86 08 13 3b ac')
# plain :  CWbytearray(b'88 15 42 52 bb 0e a7 5f e1 ba b7 43 93 1d 7e 64')
# plain :  CWbytearray(b'ce e6 e7 eb 01 22 7d 6e 36 2f 14 84 60 71 ce 51')
# plain :  CWbytearray(b'55 49 86 ff 95 c2 65 57 2e 84 e3 21 7f cd 18 7f')
# plain :  CWbytearray(b'b4 8b fb 3c f4 ce fd 68 33 07 b2 20 a9 59 1c 19')
# plain :  CWbytearray(b'92 85 f0 10 4d e6 70 05 52 e4 50 f0 77 d4 68 f1')
# plain :  CWbytearray(b'7b e1 f3 7c 97 19 fe 07 15 b1 8a f7 21 76 35 0d')
# plain :  CWbytearray(b'65 b6 7a fd 31 b9 09 4a 79 d4 42 13 9a 5e 4c 33')
# plain :  CWbytearray(b'af 6a 6b 84 fe 1a f5 d3 e4 e6 af bd 81 b9 a3 40')
# plain :  CWbytearray(b'24 c8 9a 8f 8d f4 cc cb 8c 9b 29 f3 d3 14 74 d9')
# plain :  CWbytearray(b'c5 7f 94 fc 71 14 69 cc e5 7b c0 e5 d6 c0 39 f0')
# plain :  CWbytearray(b'16 5c 79 05 a6 fe 3b a6 50 7e fb 75 02 4d 92 42')
# plain :  CWbytearray(b'c8 00 de 6c 6c d9 01 19 46 9d 50 bb eb 00 b6 51')
# plain :  CWbytearray(b'eb d1 82 92 e6 71 f0 f9 ac 9f 87 43 a6 54 fb 25')
# plain :  CWbytearray(b'dd 11 ec 76 c4 28 6e f1 52 dd d6 f6 d8 ee 50 88')
# plain :  CWbytearray(b'cc 49 e7 c7 0a 06 78 f8 15 3a fb fd c6 f6 2b 92')
# plain :  CWbytearray(b'a9 3d c3 ba 98 d2 f6 70 47 a4 9b e3 43 42 62 07')
# plain :  CWbytearray(b'71 c5 82 fd a3 c6 07 4a 29 20 8d 9a 64 0b a8 21')
# plain :  CWbytearray(b'a5 f6 3a 5d 98 89 5f 03 c0 c3 e3 5d 36 69 70 a9')
# plain :  CWbytearray(b'5b 3c 96 4b 50 3a 91 26 c4 a4 92 1a e9 b1 9f 96')
# plain :  CWbytearray(b'c3 53 97 3d f1 31 39 77 db 3f 29 82 4e 38 03 12')
# plain :  CWbytearray(b'fe 65 5a 09 cc 36 0e d9 96 a9 fe 01 b8 8f 37 a8')
# plain :  CWbytearray(b'5d aa f5 57 5e 8b 6d 42 79 a8 52 6e 84 bb 96 ad')
# plain :  CWbytearray(b'a6 e8 16 d1 6b 04 97 9d b3 d7 da 7c 70 00 25 8f')
# plain :  CWbytearray(b'dd f6 2e af cb fa 7e 66 ef f0 6f 4c 41 38 a4 e2')
# plain :  CWbytearray(b'16 51 62 84 9b 0f b3 f2 79 75 54 47 bf 94 08 79')
# plain :  CWbytearray(b'ab 41 db ea 95 e8 89 69 f8 dc c5 1c 93 45 dd 58')
# plain :  CWbytearray(b'b6 e5 5b b0 8b fb 87 cb c2 7f a2 cc 1a ec d0 f1')
# plain :  CWbytearray(b'b1 1d 02 e6 46 a7 b6 9d 96 74 e0 9d 33 48 6f 86')
# plain :  CWbytearray(b'48 bf 93 11 25 02 92 c5 1d 67 6d ef ee 09 8e c8')
# plain :  CWbytearray(b'65 e4 6d b8 e5 d0 de 12 8a 9a a4 68 b2 30 28 7b')
# plain :  CWbytearray(b'7c 74 4b 29 a7 e0 f5 c5 7a 3d ba a3 fd 2f 28 31')
# plain :  CWbytearray(b'd2 fe 94 a2 dc 78 3a ae a9 08 2b 3f 50 75 93 e2')
# plain :  CWbytearray(b'31 ac 52 25 fd bd 2f 81 56 06 2a c7 be 7a df 92')
# plain :  CWbytearray(b'9d 27 29 a3 c3 17 8c 41 1e b6 d4 8e 31 8a b4 ac')
# plain :  CWbytearray(b'4a 8f ec ff ca 19 07 40 c2 f6 c1 ae 99 b5 c1 20')
# plain :  CWbytearray(b'3d 69 8d c2 f7 e6 72 5f 85 cc f6 95 54 4e 3e 3d')
# plain :  CWbytearray(b'41 3c 99 1d 36 88 01 7b 33 51 85 ea 6e fa d8 0c')
# plain :  CWbytearray(b'33 fc 14 15 c6 b0 6c 66 fd eb e1 f4 bb 21 fe 32')
# plain :  CWbytearray(b'36 84 ab eb 4f 21 5f 73 81 dd 8b c6 bb dd e7 5b')
# plain :  CWbytearray(b'e0 c4 ac 49 75 34 ef 39 7a 96 3d 05 a5 b3 83 66')
# plain :  CWbytearray(b'78 ca 74 06 0c 90 2b 5d 0b 3e a2 96 fd 9c 6d b2')
# plain :  CWbytearray(b'e0 63 11 a8 77 03 b0 5a a7 67 09 95 be 99 99 4f')
# plain :  CWbytearray(b'f7 a8 b4 17 e3 b5 7c 25 c5 34 3e 9e 54 13 4e e1')
# plain :  CWbytearray(b'b4 2c 61 66 df d5 13 7a 64 c2 9c 52 02 44 d4 ac')
# plain :  CWbytearray(b'ac df 4d dd 3b a5 12 ba 0a 9c 68 2e 9d 97 b8 e3')
# plain :  CWbytearray(b'4a eb 59 bd 5c 0c b2 70 53 fc ba 45 ab 08 20 b6')
# plain :  CWbytearray(b'af 04 26 10 37 d5 09 b5 9a 0e 51 45 15 4f ac da')
# plain :  CWbytearray(b'53 1a 5c 30 93 0e f5 38 87 ca d5 9c 86 d2 d0 fa')
# plain :  CWbytearray(b'5b 5f 59 38 65 16 81 fd a6 28 06 9a 0c 0b 3d b1')
# plain :  CWbytearray(b'75 80 c2 74 e4 c5 89 11 97 90 0a f8 2c 65 59 8b')
# plain :  CWbytearray(b'e1 40 7f ed 40 28 ab 03 b5 a4 36 64 99 bc 6d a4')
# plain :  CWbytearray(b'e2 63 35 5c 76 e9 e0 ce 91 9a 08 fb b9 3c 9a bd')
# plain :  CWbytearray(b'3f 76 cd 52 52 f4 0d 48 88 8b 3e e6 10 66 17 4d')
# plain :  CWbytearray(b'c6 75 6b 3c 69 68 ba dd 48 32 d8 a3 a6 16 15 bf')
# plain :  CWbytearray(b'69 87 f4 8a 84 1d 4a 9f 01 a6 a6 d9 2f b3 34 09')
# plain :  CWbytearray(b'c9 bd 1a 3c 06 6f da 30 04 88 88 e7 1e 26 64 d1')
# plain :  CWbytearray(b'78 9d 00 b6 75 e1 9d b6 b6 e0 bf d9 a2 eb 70 6c')
# plain :  CWbytearray(b'e8 c4 f9 d7 46 43 35 d6 ae f3 03 4f ee 67 64 d1')
# plain :  CWbytearray(b'b3 87 77 7e ac bf a3 91 ca 01 af 94 80 63 26 f9')
# plain :  CWbytearray(b'da 69 fa 81 80 ed 52 ef b2 88 5f 3d 86 6d 29 da')
# plain :  CWbytearray(b'40 b0 67 dc 43 c2 66 26 e5 6a 9e 25 d7 4c 2c 00')
# plain :  CWbytearray(b'36 67 dd 8c cd 10 94 12 05 f5 c6 d6 2b 58 06 87')
# plain :  CWbytearray(b'b1 64 cb 77 fd 56 5c e0 bb 7b 7e bc 4a ce 17 18')
# plain :  CWbytearray(b'86 82 fb 69 2b 54 11 9a 08 eb 61 1d 6c ec 9a 27')
# plain :  CWbytearray(b'c6 15 40 51 95 a6 5b 8f 9a c6 d0 b2 4b 09 f9 32')
# plain :  CWbytearray(b'50 52 4a 5b 63 e2 90 43 5c 97 9c 33 c9 76 4d 38')
# plain :  CWbytearray(b'02 28 2c b3 18 41 f1 78 1e f8 24 b3 3d 08 36 90')
# plain :  CWbytearray(b'ea b7 72 98 b6 08 8c 35 ae 88 97 68 42 43 43 1c')
# plain :  CWbytearray(b'79 17 d0 3c 76 3a 0a bf 59 0d bf 43 65 7c 3e a0')
# plain :  CWbytearray(b'19 6e 75 b9 fa c0 fa b5 b1 81 0f 4b 23 d9 60 3e')
# plain :  CWbytearray(b'd4 15 51 c6 b6 44 c0 fe 1a 72 e5 b8 d4 b3 cf 3e')
# plain :  CWbytearray(b'06 d4 6b bb 6e 2e ce 24 24 f2 c1 08 67 0f dd b1')
# plain :  CWbytearray(b'e7 5d e8 de 62 a7 15 0f 6c e2 59 4d c0 b0 c0 1a')
# plain :  CWbytearray(b'5a 1d b3 16 b6 f9 57 99 d7 c3 24 17 1a 1a 42 2c')
# plain :  CWbytearray(b'ca c6 65 ce 1e 5e 70 80 93 6f 03 19 ac 5b bb 06')
# plain :  CWbytearray(b'3c 72 a0 9d a7 a8 57 65 52 b1 60 e1 09 b5 5b a6')
# plain :  CWbytearray(b'be f3 e2 62 e0 7b 6c 3f 17 75 e8 bd a7 6e 56 2c')
# plain :  CWbytearray(b'52 9a 5d 81 a9 3a 2b 4c 2a 62 0d 08 ba f0 72 6c')
# plain :  CWbytearray(b'1c 93 e9 9c 2a 4e 5f db 07 6f e6 d7 43 bf 0a c7')
# plain :  CWbytearray(b'27 5b 43 bf 27 f9 c6 24 10 95 82 50 e4 a9 88 c2')
# plain :  CWbytearray(b'35 25 ec e6 a7 63 46 86 c3 47 3e 9b 06 83 25 51')
# plain :  CWbytearray(b'9d 2d 65 26 ac d7 9f c5 b7 67 6b c8 47 82 0d bc')
# plain :  CWbytearray(b'bb 5b 70 0a db 05 63 a6 f2 2c 7a 14 7d 59 66 86')
# plain :  CWbytearray(b'6f 85 f8 14 b7 42 0a 72 e6 20 31 e3 9d af 01 4e')
# plain :  CWbytearray(b'c4 65 c3 2f b0 4f 7e 99 ea 27 09 9d 25 91 3e 60')
# plain :  CWbytearray(b'af ae ba 23 04 c4 40 0d 8a 09 98 94 87 6b d0 4d')
# plain :  CWbytearray(b'a5 66 fb f9 8f 2b 4f 8e b5 d5 50 94 2e d9 68 cd')
# plain :  CWbytearray(b'f7 fa 24 31 44 20 77 bd ce fb 4b c5 aa 87 cb 50')
# plain :  CWbytearray(b'ce 92 9a f5 91 22 49 53 be 7f fd 79 e2 4a 2a 92')
# plain :  CWbytearray(b'40 a0 9a 67 3a ac b2 54 8b 47 87 6b 78 bb d4 72')
# plain :  CWbytearray(b'16 eb b2 3b a0 50 a9 84 d7 90 27 1e b5 c3 d8 e7')
# plain :  CWbytearray(b'2a 23 4e c1 11 c7 69 aa 65 53 10 71 43 ad 38 68')
# plain :  CWbytearray(b'9f 3f 93 fd b5 1d 65 c1 ff ff f9 1f 18 9b 3f 7b')
# plain :  CWbytearray(b'f3 61 a9 35 0f d2 f0 79 28 4c 40 d8 35 2f 26 74')
# plain :  CWbytearray(b'31 1f c5 5f f5 75 0b ac 83 52 2f 1b 43 52 67 28')
# plain :  CWbytearray(b'9e b6 79 16 aa 40 32 7b 5e f6 6e e9 44 fa fc d9')
# plain :  CWbytearray(b'0a 56 d3 ef c1 9f a4 65 e5 4b 86 16 f2 45 40 f8')
# plain :  CWbytearray(b'60 db 17 99 66 e1 8b d3 f8 7d f1 cc 92 9b 8d bc')
# plain :  CWbytearray(b'ba 20 7d f5 40 4b f4 eb 39 36 26 c1 73 c7 3c d6')
# plain :  CWbytearray(b'd9 bd 19 9b 55 e9 42 3e 75 f5 5b d3 7b 27 ef ec')
# plain :  CWbytearray(b'fc d9 da 74 b3 ab cf 49 f9 15 2e b4 f9 75 82 2a')
# plain :  CWbytearray(b'9d 6d a2 0c 3b 32 ce 6b 41 ea 77 d1 74 b2 b0 fb')
# plain :  CWbytearray(b'da 4b 50 73 3b 6a 0b 62 53 e3 cc 96 04 3a 1e 71')
# plain :  CWbytearray(b'52 ef 4b d2 1e 9b e1 46 cb cf 29 0f 15 49 fd b9')
# plain :  CWbytearray(b'34 cb 84 03 e1 54 fe cd e4 de 72 d5 b4 3e 3c 33')
# plain :  CWbytearray(b'73 47 10 06 0d 34 ac 2f a3 65 15 3c 1f 3e 36 4a')
# plain :  CWbytearray(b'dc 5d 6d 64 2b 36 7c ef 60 b5 46 88 b8 3d f3 e4')
# plain :  CWbytearray(b'28 d8 7e f5 95 2a 4b 92 ee 91 cd 7f 77 17 ff 34')
# plain :  CWbytearray(b'56 0e c7 7f 98 6d 56 cc 5f 23 87 ba 10 b2 03 8a')
# plain :  CWbytearray(b'86 40 59 bb 3f a7 3a ef f5 1b a1 d4 13 4b 3d 21')
# plain :  CWbytearray(b'67 fd 11 5c ee 18 cd 4c 31 f7 08 5f 3c b5 10 a5')
# plain :  CWbytearray(b'02 d9 21 cf ae 05 a7 8a 49 69 85 46 44 17 c7 1f')
# plain :  CWbytearray(b'9d eb 38 54 18 41 1d 25 4f b8 c5 2b 7c dc 18 c6')
# plain :  CWbytearray(b'31 d6 9f f4 bd 15 77 1c d8 b3 2e e0 01 3b 5b 17')
# plain :  CWbytearray(b'10 40 4e 54 49 da 17 f1 d0 d4 df b6 fd 21 53 a5')
# plain :  CWbytearray(b'05 53 fc b8 48 5a b2 05 dd fc ff 5b 3a b5 13 f9')
# plain :  CWbytearray(b'81 22 41 f1 c5 eb 1b 30 0d b6 8b 4f 8c 02 46 73')
# plain :  CWbytearray(b'9d 4f 9a af 51 ea 6f f1 91 c2 6a de b5 57 36 b9')
# plain :  CWbytearray(b'e5 c3 2d 7f 3f c4 c9 8b 3f f0 66 6a c3 30 fa be')
# plain :  CWbytearray(b'9e 1f ad 03 71 34 b3 86 6f b4 9d 02 40 21 88 17')
# plain :  CWbytearray(b'18 04 7e 82 ba f0 8a 33 dc 11 5a 8b cc 56 7e 90')
# plain :  CWbytearray(b'a6 e7 6b 8d 1a 83 49 65 2c f2 d7 1d c9 82 9a 1b')
# plain :  CWbytearray(b'98 f1 86 3e d7 77 ee 32 f7 d9 47 2c 5c 53 4b 92')
# plain :  CWbytearray(b'54 37 9c 25 10 a0 a4 29 13 02 8a 09 63 40 cb 79')
# plain :  CWbytearray(b'8c 2d cd 03 00 34 1d 8f ad 52 72 97 55 7a 4f 73')
# plain :  CWbytearray(b'a2 79 93 ca 08 e7 52 73 f4 99 9b 44 2f 20 9c aa')
# plain :  CWbytearray(b'28 d5 33 38 ad 14 ad 00 c6 c3 1b f9 70 7a 1f 4d')
# plain :  CWbytearray(b'60 fe c0 31 32 e7 f5 55 ef bc d5 ec df 09 cc 9c')
# plain :  CWbytearray(b'e7 af 38 cd fd 43 be 31 c9 cd 7b d4 14 de 2d bd')
# plain :  CWbytearray(b'a5 b5 60 c1 56 02 88 31 75 f2 05 20 c0 b4 42 66')
# plain :  CWbytearray(b'68 f1 ee c9 48 e0 c9 70 e4 09 23 b0 8c c0 66 40')
# plain :  CWbytearray(b'9c a4 7a 77 e2 7d 45 28 25 15 6f f3 04 12 15 9a')
# plain :  CWbytearray(b'be 83 96 6e 09 71 a4 23 29 a1 56 e4 f0 f6 2c 9b')
# plain :  CWbytearray(b'9b 5c 3d 74 c7 6c 9e 3a b9 76 0f e8 56 22 3e 8a')
# plain :  CWbytearray(b'1e 62 f7 98 da e8 2c 28 4c 2f 8c 7a 5d d0 dc 73')
# plain :  CWbytearray(b'82 ea a0 90 b5 de 9b b7 e9 dc 10 a1 3a dc 80 29')
# plain :  CWbytearray(b'a4 2a bd 51 10 90 09 0a 0e 69 21 2a aa 14 4c 7a')
# plain :  CWbytearray(b'4f 47 b8 e8 24 f4 ca 66 6b 33 03 9e 68 82 03 3c')
# plain :  CWbytearray(b'64 bd 20 cd 59 1c c6 e0 77 d1 f9 1b 72 13 0b 0b')
# plain :  CWbytearray(b'12 a4 2e bc 58 21 9e 99 ba 64 6c 0b 13 54 f5 02')
# plain :  CWbytearray(b'a8 75 9e 0a a2 96 70 35 5d 8e 66 d8 2a d0 a8 06')
# plain :  CWbytearray(b'cf d9 ac 4a cc e4 54 99 f3 cd 85 54 8c f2 c2 c4')
# plain :  CWbytearray(b'81 05 3b f4 e6 ba fb 77 19 98 7f 57 0e 2a 53 97')
# plain :  CWbytearray(b'30 a1 08 20 28 6c 95 4d 82 ca 6a bd ca 74 37 27')
# plain :  CWbytearray(b'b6 c5 f4 1a 7a 92 1d 30 6f 36 28 41 2e ff d9 fb')
# plain :  CWbytearray(b'83 b1 a0 e7 2f 60 d4 b7 ac a3 2c b0 76 60 c0 e3')
# plain :  CWbytearray(b'a9 e5 fc 11 c0 24 c4 70 b7 6b 8f 4b 5f e0 4e 7f')
# plain :  CWbytearray(b'f1 80 9e 9b 06 99 cc 90 4c 39 49 b2 b1 c8 24 20')
# plain :  CWbytearray(b'10 81 3d 16 cc 78 94 77 92 36 93 9a 44 8e 4e 12')
# plain :  CWbytearray(b'21 70 de 97 32 0b ab 9e a3 82 a3 73 88 af 05 66')
# plain :  CWbytearray(b'82 7a 99 62 55 a5 43 8e 3d d6 f9 6b cf 4d 66 7b')
# plain :  CWbytearray(b'cb 9d 14 5a 03 3c 11 45 a1 99 42 98 1b cb 7e b5')
# plain :  CWbytearray(b'c9 6d a6 d3 78 7d 9c 9d 9c c8 5a 69 fb e2 9e 2f')
# plain :  CWbytearray(b'fb 5c 60 d7 1a fa 96 62 66 d4 2b 27 70 7f 90 a8')
# plain :  CWbytearray(b'30 06 db 10 ea be ce dc d6 bd 80 56 b2 c6 51 28')
# plain :  CWbytearray(b'a3 f9 68 77 d8 e4 4b 8b 75 46 8f 8d 0c 28 d6 66')
# plain :  CWbytearray(b'10 83 c3 7c ea 82 68 b2 27 34 3f c9 73 0a 38 5c')
# plain :  CWbytearray(b'bd c7 1c a6 98 73 96 6d 0d 79 23 c3 fc f6 33 3f')
# plain :  CWbytearray(b'e7 13 f7 47 39 d0 ff 8f de 5e 0b 29 0a 3b 53 b8')
# plain :  CWbytearray(b'ec a9 b0 4e 9d 70 ea 3f c4 69 56 4e 0d 37 fb 4e')
# plain :  CWbytearray(b'47 c5 fe a4 06 61 a7 ee 33 0c b2 09 ed 65 b3 9d')
# plain :  CWbytearray(b'f2 97 c8 77 30 c8 a4 f3 61 40 de e3 ce 5c 9a de')
# plain :  CWbytearray(b'0a 90 96 ab 6e 76 01 84 2f 44 70 50 ef b7 ef b5')
# plain :  CWbytearray(b'c7 58 2e 3b 68 00 56 db 0c 6c 56 f1 29 51 59 4e')
# plain :  CWbytearray(b'95 d4 d1 c2 fe dd 8f 21 59 16 fd d7 ed 44 24 ea')
# plain :  CWbytearray(b'7c 66 0e 6d 79 0e 15 01 a0 a3 41 fc 90 0c df 1a')
# plain :  CWbytearray(b'a5 33 5a de c1 ce d5 74 f1 4b 9b 83 8c 2e 60 92')
# plain :  CWbytearray(b'e3 00 3b 96 c1 12 c8 42 ad 5b 68 d1 40 aa 57 30')
# plain :  CWbytearray(b'33 b9 70 1d 5a 2f 4d f6 93 af 60 f0 98 26 ac 51')
# plain :  CWbytearray(b'75 62 8f 41 03 f3 17 61 ff 06 f0 c6 89 0f d6 61')
# plain :  CWbytearray(b'33 da 02 30 5b 22 6f c4 a6 21 ba 98 da 4c dd 3c')
# plain :  CWbytearray(b'65 aa bd ec ec 0c fe 67 66 b8 67 10 b2 d2 ce ef')
# plain :  CWbytearray(b'79 cd 8c ff 2d 6b 42 c4 0f c0 10 28 dd 9c 00 97')
# plain :  CWbytearray(b'b6 13 90 2f eb 76 ad 5d 4a 26 a9 73 17 f6 95 0f')

# %% [markdown]
# You must now write a C program which reads the file into an array and prints the first 10 values, using the following code skeleton, in which path is a buffer containing the file name.

# %% [markdown]
#     #define NB_SAMPLES 3000  // should be in a header file !
#
#     double traces[NB_SAMPLES];  //only one trace here, to be adapted if needed
#
#     if ((fd = open(path, O_RDONLY)) == -1) {
#         perror("open");
#         return -1;
#     }
#
#     if (read(fd, traces, sizeof(double) * NB_SAMPLES) == -1) {
#         perror("read");
#         return -1;
#     }
#
#     for (int i = 0; i < 10; i += 1) {
#         printf("%f\n", traces[i]);
#     }

# %% [markdown]
# Verify that you observe the same 10 values than in python. Change the python code above in order to convert the paintext and the key in raw type, using `astype('uint8')`, and write them in separate files.
# You can check the content of the raw key file (for example) using either the linux commands `xxd` or `hexdump`.
#
# Modify your script in order to generate raw files for a set of several traces with different random plaintexts. The file containing the traces and the file contaning the plaintext must have a length of `nb_samples * nb_traces * sizeof(double)` and `16 * nb_traces` respectively, which you can check with the linux `ls -l` command.
#
# Note: it is possible that some traces contain an incorrect number of samples. It is advised to check the length of the trace right after its capture, and redo the capture if it is incorrect.

# %% [markdown]
# # Implementing CPA

# %%
import math
# !!! just to check that I have the same results in C and in python !!!

sbox = (
    )

HW = [bin(n).count("1") for n in range(0, 256)]


def intermediate(pt, key):
    return sbox[pt ^ key]


P = []

for i in range(N):
    line = [HW[intermediate(traces[i].textin[0],k)] for k in range(256)]
    P.append(line)
P = np.array(P)


print("\n")
print("P : ",end="")
print(P[0])

print("\n")
print("H_mean : ",end="")
for i in range(10):
    print(np.mean(P[:,i])," ",end="")

print("\n")
print("traces : ",end="")
for i in range(10):
    print(traces[i].wave[0]," ",end="")

print("\n")
print("T_mean : ",end="")
for i in range(10):
    print(np.mean([t.wave[i] for t in traces])," ",end="")
# Out:
# P : [4 3 4 2 5 4 3 6 6 4 4 4 4 2 4 6 7 6 5 5 2 1 5 4 5 5 6 4 4 5 6 6 6 4 4 5 3
#  2 1 4 2 4 2 4 1 5 3 4 4 4 3 3 3 4 5 5 4 6 7 4 6 7 4 3 3 3 3 6 4 5 6 4 1 6
#  4 5 4 4 0 6 3 5 5 2 3 5 5 5 4 5 4 2 2 3 3 3 1 8 6 4 5 5 5 2 3 5 3 6 3 4 1
#  5 2 4 6 3 3 6 1 7 3 4 4 3 3 7 4 7 6 5 3 6 3 6 4 2 2 3 2 2 2 2 5 5 3 5 3 5
#  3 5 6 5 6 5 2 4 5 2 3 5 4 5 5 1 4 4 5 5 4 5 4 4 6 3 5 5 3 4 4 5 3 5 4 3 3
#  2 2 4 3 3 4 2 3 3 4 5 3 4 5 5 2 2 6 3 3 5 5 4 4 6 4 3 4 6 4 5 3 4 4 4 5 4
#  3 4 3 3 6 3 2 4 4 4 7 5 2 3 3 3 3 3 5 4 2 7 5 4 4 5 4 5 4 3 4 5 3 2]
#
#
# H_mean : 3.988  3.997  4.0136666666666665  3.969333333333333  4.005333333333334  3.9963333333333333  3.985333333333333  4.012333333333333  4.009333333333333  4.0103333333333335
#
# traces : 0.0654296875  0.0634765625  0.0498046875  0.06640625  0.0634765625  0.0615234375  0.06640625  0.0498046875  0.0615234375  0.05859375
#
# T_mean : 0.0613310546875  -0.2962666015625  -0.13730143229166666  -0.13683658854166666  0.014869140625  -0.3881806640625  -0.2040693359375  -0.18679166666666666  -0.019968098958333333  -0.45196940104166666

# %% [markdown]
# You must now implement a CPA (Correlation Power Analysis) in C, using traces that you have converted as above. It should be much faster to execute in C than in python. You must use the Pearson correlation coefficient as presented during the lectures.
#
# Your code must be as generic as possible regarding the number of samples, traces, and file names. It should allow to perform the attack on a sub-interval of the traces, by reading into memory only this sub-interval for each trace.
#
# In your report, you must present the results of an evaluation regarding the effect of the trace number on the success rate of the attack (in terms of number of key bytes correctly recovered), and compare it with the DPA results.
#
# Finally, as a bonus, you can implement the DPA attack in C in order to compare the execution time between both attacks, and between the C and the python implementation. Explain the results that you have obtained in your report.
